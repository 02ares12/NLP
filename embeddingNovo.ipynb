# %%
import torch
from transformers import BertTokenizer, BertModel
import math

# %%
# Carrega modelo BERT pré-treinado e seu tokenizer
modelName = 'neuralmind/bert-base-portuguese-cased'
tokenizer = BertTokenizer.from_pretrained(modelName)
model = BertModel.from_pretrained(modelName, output_hidden_states=True)
model.eval()
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# BertModel(
#   (embeddings): BertEmbeddings(
#     (word_embeddings): Embedding(29794, 768, padding_idx=0)
#     (position_embeddings): Embedding(512, 768)
#     (token_type_embeddings): Embedding(2, 768)
#     (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (encoder): BertEncoder(
#     (layer): ModuleList(
#       (0-11): 12 x BertLayer(
#         (attention): BertAttention(
#           (self): BertSdpaSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#   )
#   (pooler): BertPooler(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (activation): Tanh()
#   )
# )

# %%
# Lê o arquivo com frases
with open('frases2.txt','r', encoding='utf-8') as f:
    frases = f.readlines()

# %%
# Aplica o tokenizer nas frases (com padding e truncamento)
tokens = tokenizer(frases, return_tensors='pt', padding=True, truncation=True, max_length=512)

# %%
# Gera os embeddings com o modelo BERT
with torch.no_grad():
    outputs = model(**tokens)

# %%
# Lista de tensores com os embeddings de cada camada (13: emb + 12 camadas)
# Cada tensor tem shape [nFrases, nEmbeddings, 768]
embeddingsPorCamada = outputs.hidden_states

# %%
# Número de camadas, frases e embeddings por frase
nCamadas = len(embeddingsPorCamada)           # 13 camadas
nFrases = embeddingsPorCamada[0].shape[0]     # número de frases
nEmbeddings = embeddingsPorCamada[0].shape[1] # número de embeddings por frase (tokens)

# %%
# Função que calcula o ângulo (graus) entre dois vetores (sem normalizar)
def anguloEntre(v1, v2):
    produtoEscalar = (v1 * v2).sum(dim=-1)
    normaV1 = torch.norm(v1, dim=-1)
    normaV2 = torch.norm(v2, dim=-1)
    cosTheta = (produtoEscalar / (normaV1 * normaV2)).clamp(-1, 1)
    return torch.acos(cosTheta) * (180 / math.pi)

# %%
# Lista para armazenar a curvatura média de cada frase
desvioCurvaturaPorFrase = []

# %%
# Percorre todas as frases
for iFrase in range(nFrases):
    angulosPorEmbedding = []  # lista de listas de ângulos para cada embedding dessa frase

    # Percorre cada embedding (token) da frase
    for iEmbedding in range(nEmbeddings):
        angulos = []

        # Percorre pares de camadas consecutivas
        for iCamada in range(nCamadas - 1):
            vetor1 = embeddingsPorCamada[iCamada][iFrase][iEmbedding]    # vetor da camada i
            vetor2 = embeddingsPorCamada[iCamada + 1][iFrase][iEmbedding] # vetor da camada i+1

            angulo = anguloEntre(vetor1, vetor2)  # calcula o ângulo entre os vetores
            angulos.append(angulo.item())

        angulosPorEmbedding.append(angulos)  # adiciona lista de ângulos desse embedding

    # Calcula a média de curvaturas para a frase
    todosAngulos = [a for angles in angulosPorEmbedding for a in angles]
    mediaFrase = sum(todosAngulos) / len(todosAngulos) if todosAngulos else 0
    desvioCurvaturaPorFrase.append(mediaFrase)

# %%
# Exibe resultados
for i, curvatura in enumerate(desvioCurvaturaPorFrase):
    print(f"Frase {i}: curvatura média dos embeddings = {curvatura:.2f}°")
# Out:
# Frase 0: curvatura média dos embeddings = 27.56°
# Frase 1: curvatura média dos embeddings = 27.21°
# Frase 2: curvatura média dos embeddings = 27.56°
# Frase 3: curvatura média dos embeddings = 27.91°
# Frase 4: curvatura média dos embeddings = 27.73°
# Frase 5: curvatura média dos embeddings = 27.82°
# Frase 6: curvatura média dos embeddings = 28.23°
# Frase 7: curvatura média dos embeddings = 27.83°
# Frase 8: curvatura média dos embeddings = 28.23°
# Frase 9: curvatura média dos embeddings = 27.95°
# Frase 10: curvatura média dos embeddings = 27.21°
# Frase 11: curvatura média dos embeddings = 27.82°
# Frase 12: curvatura média dos embeddings = 28.21°
# Frase 13: curvatura média dos embeddings = 28.01°
# Frase 14: curvatura média dos embeddings = 28.27°
# Frase 15: curvatura média dos embeddings = 27.95°
# Frase 16: curvatura média dos embeddings = 27.83°
# Frase 17: curvatura média dos embeddings = 28.29°
# Frase 18: curvatura média dos embeddings = 28.34°
# Frase 19: curvatura média dos embeddings = 28.29°
# Frase 20: curvatura média dos embeddings = 27.56°
# Frase 21: curvatura média dos embeddings = 27.89°
# Frase 22: curvatura média dos embeddings = 27.98°
# Frase 23: curvatura média dos embeddings = 27.91°
# Frase 24: curvatura média dos embeddings = 28.27°
# Frase 25: curvatura média dos embeddings = 27.21°
# Frase 26: curvatura média dos embeddings = 28.21°
# Frase 27: curvatura média dos embeddings = 27.95°
# Frase 28: curvatura média dos embeddings = 27.75°
# Frase 29: curvatura média dos embeddings = 27.73°
# Frase 30: curvatura média dos embeddings = 28.31°
# Frase 31: curvatura média dos embeddings = 27.98°
# Frase 32: curvatura média dos embeddings = 27.83°
# Frase 33: curvatura média dos embeddings = 28.23°
# Frase 34: curvatura média dos embeddings = 28.23°
# Frase 35: curvatura média dos embeddings = 27.84°
# Frase 36: curvatura média dos embeddings = 27.66°
# Frase 37: curvatura média dos embeddings = 27.65°
# Frase 38: curvatura média dos embeddings = 28.09°
# Frase 39: curvatura média dos embeddings = 28.09°
# Frase 40: curvatura média dos embeddings = 27.56°
# Frase 41: curvatura média dos embeddings = 28.04°
# Frase 42: curvatura média dos embeddings = 28.27°
# Frase 43: curvatura média dos embeddings = 27.84°
# Frase 44: curvatura média dos embeddings = 28.31°
# Frase 45: curvatura média dos embeddings = 28.56°
# Frase 46: curvatura média dos embeddings = 27.78°
# Frase 47: curvatura média dos embeddings = 27.65°
# Frase 48: curvatura média dos embeddings = 27.98°
# Frase 49: curvatura média dos embeddings = 27.81°
# Frase 50: curvatura média dos embeddings = 28.25°
# Frase 51: curvatura média dos embeddings = 28.27°
# Frase 52: curvatura média dos embeddings = 27.95°
# Frase 53: curvatura média dos embeddings = 28.01°
# Frase 54: curvatura média dos embeddings = 28.56°
# Frase 55: curvatura média dos embeddings = 27.75°
# Frase 56: curvatura média dos embeddings = 27.81°

# %%
# Lista para guardar curvaturas espaciais por camada e por frase
curvaturaEspacialPorCamada = []

# Percorre cada camada
for iCamada in range(nCamadas):
    curvaturasFraseAtual = []

    # Percorre cada frase
    for iFrase in range(nFrases):
        angulosEntreEmbeddings = []

        # Percorre pares de embeddings consecutivos da frase
        for iEmbedding in range(nEmbeddings - 1):
            v1 = embeddingsPorCamada[iCamada][iFrase][iEmbedding]     # vetor do token i
            v2 = embeddingsPorCamada[iCamada][iFrase][iEmbedding + 1] # vetor do token i+1

            angulo = anguloEntre(v1, v2)  # ângulo entre os embeddings consecutivos
            angulosEntreEmbeddings.append(angulo.item())

        # Calcula a média dos ângulos da frase para essa camada
        mediaFrase = sum(angulosEntreEmbeddings) / len(angulosEntreEmbeddings) if angulosEntreEmbeddings else 0
        curvaturasFraseAtual.append(mediaFrase)

    # Guarda a lista de médias dessa camada (uma média por frase)
    curvaturaEspacialPorCamada.append(curvaturasFraseAtual)

# %%
for iCamada, mediasFrases in enumerate(curvaturaEspacialPorCamada):
    print(f"Camada {iCamada}:")
    for iFrase, media in enumerate(mediasFrases):
        print(f"  Frase {iFrase}: curvatura espacial média = {media:.2f}°")
# Out:
# Camada 0:
#   Frase 0: curvatura espacial média = 66.49°
#   Frase 1: curvatura espacial média = 80.99°
#   Frase 2: curvatura espacial média = 66.49°
#   Frase 3: curvatura espacial média = 72.53°
#   Frase 4: curvatura espacial média = 63.79°
#   Frase 5: curvatura espacial média = 77.77°
#   Frase 6: curvatura espacial média = 52.19°
#   Frase 7: curvatura espacial média = 66.91°
#   Frase 8: curvatura espacial média = 52.19°
#   Frase 9: curvatura espacial média = 72.39°
#   Frase 10: curvatura espacial média = 80.99°
#   Frase 11: curvatura espacial média = 77.77°
#   Frase 12: curvatura espacial média = 58.26°
#   Frase 13: curvatura espacial média = 61.64°
#   Frase 14: curvatura espacial média = 58.15°
#   Frase 15: curvatura espacial média = 72.39°
#   Frase 16: curvatura espacial média = 66.91°
#   Frase 17: curvatura espacial média = 61.04°
#   Frase 18: curvatura espacial média = 52.72°
#   Frase 19: curvatura espacial média = 61.04°
#   Frase 20: curvatura espacial média = 66.49°
#   Frase 21: curvatura espacial média = 66.79°
#   Frase 22: curvatura espacial média = 50.40°
#   Frase 23: curvatura espacial média = 72.53°
#   Frase 24: curvatura espacial média = 58.15°
#   Frase 25: curvatura espacial média = 80.99°
#   Frase 26: curvatura espacial média = 58.26°
#   Frase 27: curvatura espacial média = 72.39°
#   Frase 28: curvatura espacial média = 57.94°
#   Frase 29: curvatura espacial média = 63.79°
#   Frase 30: curvatura espacial média = 63.18°
#   Frase 31: curvatura espacial média = 50.40°
#   Frase 32: curvatura espacial média = 66.91°
#   Frase 33: curvatura espacial média = 52.19°
#   Frase 34: curvatura espacial média = 52.19°
#   Frase 35: curvatura espacial média = 83.97°
#   Frase 36: curvatura espacial média = 58.45°
#   Frase 37: curvatura espacial média = 69.86°
#   Frase 38: curvatura espacial média = 57.87°
#   Frase 39: curvatura espacial média = 57.87°
#   Frase 40: curvatura espacial média = 66.49°
#   Frase 41: curvatura espacial média = 63.73°
#   Frase 42: curvatura espacial média = 66.59°
#   Frase 43: curvatura espacial média = 83.97°
#   Frase 44: curvatura espacial média = 63.18°
#   Frase 45: curvatura espacial média = 52.27°
#   Frase 46: curvatura espacial média = 71.72°
#   Frase 47: curvatura espacial média = 69.86°
#   Frase 48: curvatura espacial média = 50.40°
#   Frase 49: curvatura espacial média = 66.34°
#   Frase 50: curvatura espacial média = 63.60°
#   Frase 51: curvatura espacial média = 66.59°
#   Frase 52: curvatura espacial média = 72.39°
#   Frase 53: curvatura espacial média = 61.64°
#   Frase 54: curvatura espacial média = 52.27°
#   Frase 55: curvatura espacial média = 57.94°
#   Frase 56: curvatura espacial média = 66.34°
# Camada 1:
#   Frase 0: curvatura espacial média = 56.58°
#   Frase 1: curvatura espacial média = 68.70°
#   Frase 2: curvatura espacial média = 56.58°
#   Frase 3: curvatura espacial média = 62.46°
#   Frase 4: curvatura espacial média = 53.71°
#   Frase 5: curvatura espacial média = 66.86°
#   Frase 6: curvatura espacial média = 42.72°
#   Frase 7: curvatura espacial média = 57.11°
#   Frase 8: curvatura espacial média = 42.72°
#   Frase 9: curvatura espacial média = 61.78°
#   Frase 10: curvatura espacial média = 68.70°
#   Frase 11: curvatura espacial média = 66.86°
#   Frase 12: curvatura espacial média = 48.56°
#   Frase 13: curvatura espacial média = 52.09°
#   Frase 14: curvatura espacial média = 49.01°
#   Frase 15: curvatura espacial média = 61.78°
#   Frase 16: curvatura espacial média = 57.11°
#   Frase 17: curvatura espacial média = 50.74°
#   Frase 18: curvatura espacial média = 43.84°
#   Frase 19: curvatura espacial média = 50.74°
#   Frase 20: curvatura espacial média = 56.58°
#   Frase 21: curvatura espacial média = 56.45°
#   Frase 22: curvatura espacial média = 41.64°
#   Frase 23: curvatura espacial média = 62.46°
#   Frase 24: curvatura espacial média = 49.01°
#   Frase 25: curvatura espacial média = 68.70°
#   Frase 26: curvatura espacial média = 48.56°
#   Frase 27: curvatura espacial média = 61.78°
#   Frase 28: curvatura espacial média = 47.69°
#   Frase 29: curvatura espacial média = 53.71°
#   Frase 30: curvatura espacial média = 52.92°
#   Frase 31: curvatura espacial média = 41.64°
#   Frase 32: curvatura espacial média = 57.11°
#   Frase 33: curvatura espacial média = 42.72°
#   Frase 34: curvatura espacial média = 42.72°
#   Frase 35: curvatura espacial média = 74.08°
#   Frase 36: curvatura espacial média = 49.10°
#   Frase 37: curvatura espacial média = 59.97°
#   Frase 38: curvatura espacial média = 48.49°
#   Frase 39: curvatura espacial média = 48.49°
#   Frase 40: curvatura espacial média = 56.58°
#   Frase 41: curvatura espacial média = 53.11°
#   Frase 42: curvatura espacial média = 56.38°
#   Frase 43: curvatura espacial média = 74.08°
#   Frase 44: curvatura espacial média = 52.92°
#   Frase 45: curvatura espacial média = 41.32°
#   Frase 46: curvatura espacial média = 60.94°
#   Frase 47: curvatura espacial média = 59.97°
#   Frase 48: curvatura espacial média = 41.64°
#   Frase 49: curvatura espacial média = 56.46°
#   Frase 50: curvatura espacial média = 53.12°
#   Frase 51: curvatura espacial média = 56.38°
#   Frase 52: curvatura espacial média = 61.78°
#   Frase 53: curvatura espacial média = 52.09°
#   Frase 54: curvatura espacial média = 41.32°
#   Frase 55: curvatura espacial média = 47.69°
#   Frase 56: curvatura espacial média = 56.46°
# Camada 2:
#   Frase 0: curvatura espacial média = 58.59°
#   Frase 1: curvatura espacial média = 68.74°
#   Frase 2: curvatura espacial média = 58.59°
#   Frase 3: curvatura espacial média = 63.84°
#   Frase 4: curvatura espacial média = 56.07°
#   Frase 5: curvatura espacial média = 67.82°
#   Frase 6: curvatura espacial média = 46.81°
#   Frase 7: curvatura espacial média = 58.69°
#   Frase 8: curvatura espacial média = 46.81°
#   Frase 9: curvatura espacial média = 61.69°
#   Frase 10: curvatura espacial média = 68.74°
#   Frase 11: curvatura espacial média = 67.82°
#   Frase 12: curvatura espacial média = 51.19°
#   Frase 13: curvatura espacial média = 54.47°
#   Frase 14: curvatura espacial média = 52.02°
#   Frase 15: curvatura espacial média = 61.69°
#   Frase 16: curvatura espacial média = 58.69°
#   Frase 17: curvatura espacial média = 52.85°
#   Frase 18: curvatura espacial média = 48.07°
#   Frase 19: curvatura espacial média = 52.85°
#   Frase 20: curvatura espacial média = 58.59°
#   Frase 21: curvatura espacial média = 58.50°
#   Frase 22: curvatura espacial média = 44.74°
#   Frase 23: curvatura espacial média = 63.84°
#   Frase 24: curvatura espacial média = 52.02°
#   Frase 25: curvatura espacial média = 68.74°
#   Frase 26: curvatura espacial média = 51.19°
#   Frase 27: curvatura espacial média = 61.69°
#   Frase 28: curvatura espacial média = 51.42°
#   Frase 29: curvatura espacial média = 56.07°
#   Frase 30: curvatura espacial média = 56.09°
#   Frase 31: curvatura espacial média = 44.74°
#   Frase 32: curvatura espacial média = 58.69°
#   Frase 33: curvatura espacial média = 46.81°
#   Frase 34: curvatura espacial média = 46.81°
#   Frase 35: curvatura espacial média = 73.73°
#   Frase 36: curvatura espacial média = 52.58°
#   Frase 37: curvatura espacial média = 61.29°
#   Frase 38: curvatura espacial média = 52.28°
#   Frase 39: curvatura espacial média = 52.28°
#   Frase 40: curvatura espacial média = 58.59°
#   Frase 41: curvatura espacial média = 56.79°
#   Frase 42: curvatura espacial média = 58.43°
#   Frase 43: curvatura espacial média = 73.73°
#   Frase 44: curvatura espacial média = 56.09°
#   Frase 45: curvatura espacial média = 45.17°
#   Frase 46: curvatura espacial média = 63.45°
#   Frase 47: curvatura espacial média = 61.29°
#   Frase 48: curvatura espacial média = 44.74°
#   Frase 49: curvatura espacial média = 57.79°
#   Frase 50: curvatura espacial média = 56.45°
#   Frase 51: curvatura espacial média = 58.43°
#   Frase 52: curvatura espacial média = 61.69°
#   Frase 53: curvatura espacial média = 54.47°
#   Frase 54: curvatura espacial média = 45.17°
#   Frase 55: curvatura espacial média = 51.42°
#   Frase 56: curvatura espacial média = 57.79°
# Camada 3:
#   Frase 0: curvatura espacial média = 53.34°
#   Frase 1: curvatura espacial média = 62.49°
#   Frase 2: curvatura espacial média = 53.34°
#   Frase 3: curvatura espacial média = 58.76°
#   Frase 4: curvatura espacial média = 51.22°
#   Frase 5: curvatura espacial média = 62.47°
#   Frase 6: curvatura espacial média = 43.37°
#   Frase 7: curvatura espacial média = 53.50°
#   Frase 8: curvatura espacial média = 43.37°
#   Frase 9: curvatura espacial média = 55.62°
#   Frase 10: curvatura espacial média = 62.49°
#   Frase 11: curvatura espacial média = 62.47°
#   Frase 12: curvatura espacial média = 46.47°
#   Frase 13: curvatura espacial média = 49.02°
#   Frase 14: curvatura espacial média = 47.07°
#   Frase 15: curvatura espacial média = 55.62°
#   Frase 16: curvatura espacial média = 53.50°
#   Frase 17: curvatura espacial média = 48.64°
#   Frase 18: curvatura espacial média = 43.83°
#   Frase 19: curvatura espacial média = 48.64°
#   Frase 20: curvatura espacial média = 53.34°
#   Frase 21: curvatura espacial média = 53.85°
#   Frase 22: curvatura espacial média = 40.87°
#   Frase 23: curvatura espacial média = 58.76°
#   Frase 24: curvatura espacial média = 47.07°
#   Frase 25: curvatura espacial média = 62.49°
#   Frase 26: curvatura espacial média = 46.47°
#   Frase 27: curvatura espacial média = 55.62°
#   Frase 28: curvatura espacial média = 46.36°
#   Frase 29: curvatura espacial média = 51.22°
#   Frase 30: curvatura espacial média = 50.87°
#   Frase 31: curvatura espacial média = 40.87°
#   Frase 32: curvatura espacial média = 53.50°
#   Frase 33: curvatura espacial média = 43.37°
#   Frase 34: curvatura espacial média = 43.37°
#   Frase 35: curvatura espacial média = 67.78°
#   Frase 36: curvatura espacial média = 48.48°
#   Frase 37: curvatura espacial média = 56.24°
#   Frase 38: curvatura espacial média = 47.22°
#   Frase 39: curvatura espacial média = 47.22°
#   Frase 40: curvatura espacial média = 53.34°
#   Frase 41: curvatura espacial média = 52.96°
#   Frase 42: curvatura espacial média = 53.48°
#   Frase 43: curvatura espacial média = 67.78°
#   Frase 44: curvatura espacial média = 50.87°
#   Frase 45: curvatura espacial média = 41.74°
#   Frase 46: curvatura espacial média = 57.43°
#   Frase 47: curvatura espacial média = 56.24°
#   Frase 48: curvatura espacial média = 40.87°
#   Frase 49: curvatura espacial média = 52.02°
#   Frase 50: curvatura espacial média = 52.41°
#   Frase 51: curvatura espacial média = 53.48°
#   Frase 52: curvatura espacial média = 55.62°
#   Frase 53: curvatura espacial média = 49.02°
#   Frase 54: curvatura espacial média = 41.74°
#   Frase 55: curvatura espacial média = 46.36°
#   Frase 56: curvatura espacial média = 52.02°
# Camada 4:
#   Frase 0: curvatura espacial média = 52.21°
#   Frase 1: curvatura espacial média = 60.93°
#   Frase 2: curvatura espacial média = 52.21°
#   Frase 3: curvatura espacial média = 57.28°
#   Frase 4: curvatura espacial média = 50.35°
#   Frase 5: curvatura espacial média = 60.88°
#   Frase 6: curvatura espacial média = 44.64°
#   Frase 7: curvatura espacial média = 51.55°
#   Frase 8: curvatura espacial média = 44.64°
#   Frase 9: curvatura espacial média = 53.45°
#   Frase 10: curvatura espacial média = 60.93°
#   Frase 11: curvatura espacial média = 60.88°
#   Frase 12: curvatura espacial média = 46.73°
#   Frase 13: curvatura espacial média = 48.25°
#   Frase 14: curvatura espacial média = 46.16°
#   Frase 15: curvatura espacial média = 53.45°
#   Frase 16: curvatura espacial média = 51.55°
#   Frase 17: curvatura espacial média = 48.88°
#   Frase 18: curvatura espacial média = 44.77°
#   Frase 19: curvatura espacial média = 48.88°
#   Frase 20: curvatura espacial média = 52.21°
#   Frase 21: curvatura espacial média = 53.39°
#   Frase 22: curvatura espacial média = 41.08°
#   Frase 23: curvatura espacial média = 57.28°
#   Frase 24: curvatura espacial média = 46.16°
#   Frase 25: curvatura espacial média = 60.93°
#   Frase 26: curvatura espacial média = 46.73°
#   Frase 27: curvatura espacial média = 53.45°
#   Frase 28: curvatura espacial média = 46.77°
#   Frase 29: curvatura espacial média = 50.35°
#   Frase 30: curvatura espacial média = 49.81°
#   Frase 31: curvatura espacial média = 41.08°
#   Frase 32: curvatura espacial média = 51.55°
#   Frase 33: curvatura espacial média = 44.64°
#   Frase 34: curvatura espacial média = 44.64°
#   Frase 35: curvatura espacial média = 63.96°
#   Frase 36: curvatura espacial média = 48.26°
#   Frase 37: curvatura espacial média = 54.38°
#   Frase 38: curvatura espacial média = 47.10°
#   Frase 39: curvatura espacial média = 47.10°
#   Frase 40: curvatura espacial média = 52.21°
#   Frase 41: curvatura espacial média = 52.66°
#   Frase 42: curvatura espacial média = 52.11°
#   Frase 43: curvatura espacial média = 63.96°
#   Frase 44: curvatura espacial média = 49.81°
#   Frase 45: curvatura espacial média = 41.98°
#   Frase 46: curvatura espacial média = 55.68°
#   Frase 47: curvatura espacial média = 54.38°
#   Frase 48: curvatura espacial média = 41.08°
#   Frase 49: curvatura espacial média = 50.72°
#   Frase 50: curvatura espacial média = 52.46°
#   Frase 51: curvatura espacial média = 52.11°
#   Frase 52: curvatura espacial média = 53.45°
#   Frase 53: curvatura espacial média = 48.25°
#   Frase 54: curvatura espacial média = 41.98°
#   Frase 55: curvatura espacial média = 46.77°
#   Frase 56: curvatura espacial média = 50.72°
# Camada 5:
#   Frase 0: curvatura espacial média = 47.41°
#   Frase 1: curvatura espacial média = 57.61°
#   Frase 2: curvatura espacial média = 47.41°
#   Frase 3: curvatura espacial média = 53.11°
#   Frase 4: curvatura espacial média = 47.02°
#   Frase 5: curvatura espacial média = 57.02°
#   Frase 6: curvatura espacial média = 41.56°
#   Frase 7: curvatura espacial média = 47.40°
#   Frase 8: curvatura espacial média = 41.56°
#   Frase 9: curvatura espacial média = 49.76°
#   Frase 10: curvatura espacial média = 57.61°
#   Frase 11: curvatura espacial média = 57.02°
#   Frase 12: curvatura espacial média = 44.47°
#   Frase 13: curvatura espacial média = 44.76°
#   Frase 14: curvatura espacial média = 42.11°
#   Frase 15: curvatura espacial média = 49.76°
#   Frase 16: curvatura espacial média = 47.40°
#   Frase 17: curvatura espacial média = 46.00°
#   Frase 18: curvatura espacial média = 42.05°
#   Frase 19: curvatura espacial média = 46.00°
#   Frase 20: curvatura espacial média = 47.41°
#   Frase 21: curvatura espacial média = 49.75°
#   Frase 22: curvatura espacial média = 38.32°
#   Frase 23: curvatura espacial média = 53.11°
#   Frase 24: curvatura espacial média = 42.11°
#   Frase 25: curvatura espacial média = 57.61°
#   Frase 26: curvatura espacial média = 44.47°
#   Frase 27: curvatura espacial média = 49.76°
#   Frase 28: curvatura espacial média = 44.60°
#   Frase 29: curvatura espacial média = 47.02°
#   Frase 30: curvatura espacial média = 45.58°
#   Frase 31: curvatura espacial média = 38.32°
#   Frase 32: curvatura espacial média = 47.40°
#   Frase 33: curvatura espacial média = 41.56°
#   Frase 34: curvatura espacial média = 41.56°
#   Frase 35: curvatura espacial média = 57.94°
#   Frase 36: curvatura espacial média = 45.82°
#   Frase 37: curvatura espacial média = 50.11°
#   Frase 38: curvatura espacial média = 43.31°
#   Frase 39: curvatura espacial média = 43.31°
#   Frase 40: curvatura espacial média = 47.41°
#   Frase 41: curvatura espacial média = 48.53°
#   Frase 42: curvatura espacial média = 47.68°
#   Frase 43: curvatura espacial média = 57.94°
#   Frase 44: curvatura espacial média = 45.58°
#   Frase 45: curvatura espacial média = 39.35°
#   Frase 46: curvatura espacial média = 51.63°
#   Frase 47: curvatura espacial média = 50.11°
#   Frase 48: curvatura espacial média = 38.32°
#   Frase 49: curvatura espacial média = 46.42°
#   Frase 50: curvatura espacial média = 48.76°
#   Frase 51: curvatura espacial média = 47.68°
#   Frase 52: curvatura espacial média = 49.76°
#   Frase 53: curvatura espacial média = 44.76°
#   Frase 54: curvatura espacial média = 39.35°
#   Frase 55: curvatura espacial média = 44.60°
#   Frase 56: curvatura espacial média = 46.42°
# Camada 6:
#   Frase 0: curvatura espacial média = 44.51°
#   Frase 1: curvatura espacial média = 54.30°
#   Frase 2: curvatura espacial média = 44.51°
#   Frase 3: curvatura espacial média = 49.51°
#   Frase 4: curvatura espacial média = 43.70°
#   Frase 5: curvatura espacial média = 53.36°
#   Frase 6: curvatura espacial média = 39.30°
#   Frase 7: curvatura espacial média = 44.66°
#   Frase 8: curvatura espacial média = 39.30°
#   Frase 9: curvatura espacial média = 46.67°
#   Frase 10: curvatura espacial média = 54.30°
#   Frase 11: curvatura espacial média = 53.36°
#   Frase 12: curvatura espacial média = 42.23°
#   Frase 13: curvatura espacial média = 43.29°
#   Frase 14: curvatura espacial média = 38.96°
#   Frase 15: curvatura espacial média = 46.67°
#   Frase 16: curvatura espacial média = 44.66°
#   Frase 17: curvatura espacial média = 43.67°
#   Frase 18: curvatura espacial média = 39.47°
#   Frase 19: curvatura espacial média = 43.67°
#   Frase 20: curvatura espacial média = 44.51°
#   Frase 21: curvatura espacial média = 47.25°
#   Frase 22: curvatura espacial média = 36.18°
#   Frase 23: curvatura espacial média = 49.51°
#   Frase 24: curvatura espacial média = 38.96°
#   Frase 25: curvatura espacial média = 54.30°
#   Frase 26: curvatura espacial média = 42.23°
#   Frase 27: curvatura espacial média = 46.67°
#   Frase 28: curvatura espacial média = 42.15°
#   Frase 29: curvatura espacial média = 43.70°
#   Frase 30: curvatura espacial média = 42.72°
#   Frase 31: curvatura espacial média = 36.18°
#   Frase 32: curvatura espacial média = 44.66°
#   Frase 33: curvatura espacial média = 39.30°
#   Frase 34: curvatura espacial média = 39.30°
#   Frase 35: curvatura espacial média = 54.56°
#   Frase 36: curvatura espacial média = 43.34°
#   Frase 37: curvatura espacial média = 46.46°
#   Frase 38: curvatura espacial média = 40.86°
#   Frase 39: curvatura espacial média = 40.86°
#   Frase 40: curvatura espacial média = 44.51°
#   Frase 41: curvatura espacial média = 46.11°
#   Frase 42: curvatura espacial média = 45.31°
#   Frase 43: curvatura espacial média = 54.56°
#   Frase 44: curvatura espacial média = 42.72°
#   Frase 45: curvatura espacial média = 36.88°
#   Frase 46: curvatura espacial média = 48.18°
#   Frase 47: curvatura espacial média = 46.46°
#   Frase 48: curvatura espacial média = 36.18°
#   Frase 49: curvatura espacial média = 43.42°
#   Frase 50: curvatura espacial média = 46.25°
#   Frase 51: curvatura espacial média = 45.31°
#   Frase 52: curvatura espacial média = 46.67°
#   Frase 53: curvatura espacial média = 43.29°
#   Frase 54: curvatura espacial média = 36.88°
#   Frase 55: curvatura espacial média = 42.15°
#   Frase 56: curvatura espacial média = 43.42°
# Camada 7:
#   Frase 0: curvatura espacial média = 46.56°
#   Frase 1: curvatura espacial média = 55.63°
#   Frase 2: curvatura espacial média = 46.56°
#   Frase 3: curvatura espacial média = 51.71°
#   Frase 4: curvatura espacial média = 46.48°
#   Frase 5: curvatura espacial média = 54.88°
#   Frase 6: curvatura espacial média = 42.06°
#   Frase 7: curvatura espacial média = 46.34°
#   Frase 8: curvatura espacial média = 42.06°
#   Frase 9: curvatura espacial média = 47.12°
#   Frase 10: curvatura espacial média = 55.63°
#   Frase 11: curvatura espacial média = 54.88°
#   Frase 12: curvatura espacial média = 43.89°
#   Frase 13: curvatura espacial média = 46.26°
#   Frase 14: curvatura espacial média = 39.81°
#   Frase 15: curvatura espacial média = 47.12°
#   Frase 16: curvatura espacial média = 46.34°
#   Frase 17: curvatura espacial média = 45.70°
#   Frase 18: curvatura espacial média = 41.69°
#   Frase 19: curvatura espacial média = 45.70°
#   Frase 20: curvatura espacial média = 46.56°
#   Frase 21: curvatura espacial média = 50.29°
#   Frase 22: curvatura espacial média = 38.24°
#   Frase 23: curvatura espacial média = 51.71°
#   Frase 24: curvatura espacial média = 39.81°
#   Frase 25: curvatura espacial média = 55.63°
#   Frase 26: curvatura espacial média = 43.89°
#   Frase 27: curvatura espacial média = 47.12°
#   Frase 28: curvatura espacial média = 43.86°
#   Frase 29: curvatura espacial média = 46.48°
#   Frase 30: curvatura espacial média = 46.00°
#   Frase 31: curvatura espacial média = 38.24°
#   Frase 32: curvatura espacial média = 46.34°
#   Frase 33: curvatura espacial média = 42.06°
#   Frase 34: curvatura espacial média = 42.06°
#   Frase 35: curvatura espacial média = 56.96°
#   Frase 36: curvatura espacial média = 46.76°
#   Frase 37: curvatura espacial média = 47.98°
#   Frase 38: curvatura espacial média = 43.51°
#   Frase 39: curvatura espacial média = 43.51°
#   Frase 40: curvatura espacial média = 46.56°
#   Frase 41: curvatura espacial média = 50.89°
#   Frase 42: curvatura espacial média = 47.07°
#   Frase 43: curvatura espacial média = 56.96°
#   Frase 44: curvatura espacial média = 46.00°
#   Frase 45: curvatura espacial média = 39.48°
#   Frase 46: curvatura espacial média = 49.67°
#   Frase 47: curvatura espacial média = 47.98°
#   Frase 48: curvatura espacial média = 38.24°
#   Frase 49: curvatura espacial média = 44.56°
#   Frase 50: curvatura espacial média = 48.38°
#   Frase 51: curvatura espacial média = 47.07°
#   Frase 52: curvatura espacial média = 47.12°
#   Frase 53: curvatura espacial média = 46.26°
#   Frase 54: curvatura espacial média = 39.48°
#   Frase 55: curvatura espacial média = 43.86°
#   Frase 56: curvatura espacial média = 44.56°
# Camada 8:
#   Frase 0: curvatura espacial média = 48.40°
#   Frase 1: curvatura espacial média = 57.53°
#   Frase 2: curvatura espacial média = 48.40°
#   Frase 3: curvatura espacial média = 53.86°
#   Frase 4: curvatura espacial média = 48.44°
#   Frase 5: curvatura espacial média = 56.32°
#   Frase 6: curvatura espacial média = 44.75°
#   Frase 7: curvatura espacial média = 48.38°
#   Frase 8: curvatura espacial média = 44.75°
#   Frase 9: curvatura espacial média = 48.58°
#   Frase 10: curvatura espacial média = 57.53°
#   Frase 11: curvatura espacial média = 56.32°
#   Frase 12: curvatura espacial média = 47.00°
#   Frase 13: curvatura espacial média = 48.28°
#   Frase 14: curvatura espacial média = 42.11°
#   Frase 15: curvatura espacial média = 48.58°
#   Frase 16: curvatura espacial média = 48.38°
#   Frase 17: curvatura espacial média = 48.56°
#   Frase 18: curvatura espacial média = 44.39°
#   Frase 19: curvatura espacial média = 48.56°
#   Frase 20: curvatura espacial média = 48.40°
#   Frase 21: curvatura espacial média = 52.08°
#   Frase 22: curvatura espacial média = 41.30°
#   Frase 23: curvatura espacial média = 53.86°
#   Frase 24: curvatura espacial média = 42.11°
#   Frase 25: curvatura espacial média = 57.53°
#   Frase 26: curvatura espacial média = 47.00°
#   Frase 27: curvatura espacial média = 48.58°
#   Frase 28: curvatura espacial média = 46.25°
#   Frase 29: curvatura espacial média = 48.44°
#   Frase 30: curvatura espacial média = 50.43°
#   Frase 31: curvatura espacial média = 41.30°
#   Frase 32: curvatura espacial média = 48.38°
#   Frase 33: curvatura espacial média = 44.75°
#   Frase 34: curvatura espacial média = 44.75°
#   Frase 35: curvatura espacial média = 58.48°
#   Frase 36: curvatura espacial média = 49.53°
#   Frase 37: curvatura espacial média = 48.35°
#   Frase 38: curvatura espacial média = 46.43°
#   Frase 39: curvatura espacial média = 46.43°
#   Frase 40: curvatura espacial média = 48.40°
#   Frase 41: curvatura espacial média = 53.29°
#   Frase 42: curvatura espacial média = 49.66°
#   Frase 43: curvatura espacial média = 58.48°
#   Frase 44: curvatura espacial média = 50.43°
#   Frase 45: curvatura espacial média = 42.35°
#   Frase 46: curvatura espacial média = 52.17°
#   Frase 47: curvatura espacial média = 48.35°
#   Frase 48: curvatura espacial média = 41.30°
#   Frase 49: curvatura espacial média = 46.39°
#   Frase 50: curvatura espacial média = 50.02°
#   Frase 51: curvatura espacial média = 49.66°
#   Frase 52: curvatura espacial média = 48.58°
#   Frase 53: curvatura espacial média = 48.28°
#   Frase 54: curvatura espacial média = 42.35°
#   Frase 55: curvatura espacial média = 46.25°
#   Frase 56: curvatura espacial média = 46.39°
# Camada 9:
#   Frase 0: curvatura espacial média = 48.96°
#   Frase 1: curvatura espacial média = 58.39°
#   Frase 2: curvatura espacial média = 48.96°
#   Frase 3: curvatura espacial média = 54.54°
#   Frase 4: curvatura espacial média = 50.72°
#   Frase 5: curvatura espacial média = 56.16°
#   Frase 6: curvatura espacial média = 46.17°
#   Frase 7: curvatura espacial média = 48.88°
#   Frase 8: curvatura espacial média = 46.17°
#   Frase 9: curvatura espacial média = 48.68°
#   Frase 10: curvatura espacial média = 58.39°
#   Frase 11: curvatura espacial média = 56.16°
#   Frase 12: curvatura espacial média = 49.08°
#   Frase 13: curvatura espacial média = 48.86°
#   Frase 14: curvatura espacial média = 42.39°
#   Frase 15: curvatura espacial média = 48.68°
#   Frase 16: curvatura espacial média = 48.88°
#   Frase 17: curvatura espacial média = 49.65°
#   Frase 18: curvatura espacial média = 45.60°
#   Frase 19: curvatura espacial média = 49.65°
#   Frase 20: curvatura espacial média = 48.96°
#   Frase 21: curvatura espacial média = 52.61°
#   Frase 22: curvatura espacial média = 42.38°
#   Frase 23: curvatura espacial média = 54.54°
#   Frase 24: curvatura espacial média = 42.39°
#   Frase 25: curvatura espacial média = 58.39°
#   Frase 26: curvatura espacial média = 49.08°
#   Frase 27: curvatura espacial média = 48.68°
#   Frase 28: curvatura espacial média = 48.48°
#   Frase 29: curvatura espacial média = 50.72°
#   Frase 30: curvatura espacial média = 51.18°
#   Frase 31: curvatura espacial média = 42.38°
#   Frase 32: curvatura espacial média = 48.88°
#   Frase 33: curvatura espacial média = 46.17°
#   Frase 34: curvatura espacial média = 46.17°
#   Frase 35: curvatura espacial média = 57.80°
#   Frase 36: curvatura espacial média = 50.90°
#   Frase 37: curvatura espacial média = 48.91°
#   Frase 38: curvatura espacial média = 47.61°
#   Frase 39: curvatura espacial média = 47.61°
#   Frase 40: curvatura espacial média = 48.96°
#   Frase 41: curvatura espacial média = 53.99°
#   Frase 42: curvatura espacial média = 50.28°
#   Frase 43: curvatura espacial média = 57.80°
#   Frase 44: curvatura espacial média = 51.18°
#   Frase 45: curvatura espacial média = 43.63°
#   Frase 46: curvatura espacial média = 53.11°
#   Frase 47: curvatura espacial média = 48.91°
#   Frase 48: curvatura espacial média = 42.38°
#   Frase 49: curvatura espacial média = 46.40°
#   Frase 50: curvatura espacial média = 50.43°
#   Frase 51: curvatura espacial média = 50.28°
#   Frase 52: curvatura espacial média = 48.68°
#   Frase 53: curvatura espacial média = 48.86°
#   Frase 54: curvatura espacial média = 43.63°
#   Frase 55: curvatura espacial média = 48.48°
#   Frase 56: curvatura espacial média = 46.40°
# Camada 10:
#   Frase 0: curvatura espacial média = 44.43°
#   Frase 1: curvatura espacial média = 54.23°
#   Frase 2: curvatura espacial média = 44.43°
#   Frase 3: curvatura espacial média = 50.71°
#   Frase 4: curvatura espacial média = 45.85°
#   Frase 5: curvatura espacial média = 52.05°
#   Frase 6: curvatura espacial média = 42.86°
#   Frase 7: curvatura espacial média = 47.31°
#   Frase 8: curvatura espacial média = 42.86°
#   Frase 9: curvatura espacial média = 46.09°
#   Frase 10: curvatura espacial média = 54.23°
#   Frase 11: curvatura espacial média = 52.05°
#   Frase 12: curvatura espacial média = 46.18°
#   Frase 13: curvatura espacial média = 45.09°
#   Frase 14: curvatura espacial média = 39.64°
#   Frase 15: curvatura espacial média = 46.09°
#   Frase 16: curvatura espacial média = 47.31°
#   Frase 17: curvatura espacial média = 45.62°
#   Frase 18: curvatura espacial média = 41.49°
#   Frase 19: curvatura espacial média = 45.62°
#   Frase 20: curvatura espacial média = 44.43°
#   Frase 21: curvatura espacial média = 48.70°
#   Frase 22: curvatura espacial média = 40.14°
#   Frase 23: curvatura espacial média = 50.71°
#   Frase 24: curvatura espacial média = 39.64°
#   Frase 25: curvatura espacial média = 54.23°
#   Frase 26: curvatura espacial média = 46.18°
#   Frase 27: curvatura espacial média = 46.09°
#   Frase 28: curvatura espacial média = 45.79°
#   Frase 29: curvatura espacial média = 45.85°
#   Frase 30: curvatura espacial média = 47.50°
#   Frase 31: curvatura espacial média = 40.14°
#   Frase 32: curvatura espacial média = 47.31°
#   Frase 33: curvatura espacial média = 42.86°
#   Frase 34: curvatura espacial média = 42.86°
#   Frase 35: curvatura espacial média = 53.86°
#   Frase 36: curvatura espacial média = 45.66°
#   Frase 37: curvatura espacial média = 45.13°
#   Frase 38: curvatura espacial média = 44.07°
#   Frase 39: curvatura espacial média = 44.07°
#   Frase 40: curvatura espacial média = 44.43°
#   Frase 41: curvatura espacial média = 50.47°
#   Frase 42: curvatura espacial média = 48.76°
#   Frase 43: curvatura espacial média = 53.86°
#   Frase 44: curvatura espacial média = 47.50°
#   Frase 45: curvatura espacial média = 40.32°
#   Frase 46: curvatura espacial média = 50.63°
#   Frase 47: curvatura espacial média = 45.13°
#   Frase 48: curvatura espacial média = 40.14°
#   Frase 49: curvatura espacial média = 42.93°
#   Frase 50: curvatura espacial média = 45.77°
#   Frase 51: curvatura espacial média = 48.76°
#   Frase 52: curvatura espacial média = 46.09°
#   Frase 53: curvatura espacial média = 45.09°
#   Frase 54: curvatura espacial média = 40.32°
#   Frase 55: curvatura espacial média = 45.79°
#   Frase 56: curvatura espacial média = 42.93°
# Camada 11:
#   Frase 0: curvatura espacial média = 38.41°
#   Frase 1: curvatura espacial média = 48.00°
#   Frase 2: curvatura espacial média = 38.41°
#   Frase 3: curvatura espacial média = 45.76°
#   Frase 4: curvatura espacial média = 39.10°
#   Frase 5: curvatura espacial média = 46.13°
#   Frase 6: curvatura espacial média = 37.75°
#   Frase 7: curvatura espacial média = 43.56°
#   Frase 8: curvatura espacial média = 37.75°
#   Frase 9: curvatura espacial média = 41.28°
#   Frase 10: curvatura espacial média = 48.00°
#   Frase 11: curvatura espacial média = 46.13°
#   Frase 12: curvatura espacial média = 40.08°
#   Frase 13: curvatura espacial média = 39.76°
#   Frase 14: curvatura espacial média = 35.62°
#   Frase 15: curvatura espacial média = 41.28°
#   Frase 16: curvatura espacial média = 43.56°
#   Frase 17: curvatura espacial média = 39.63°
#   Frase 18: curvatura espacial média = 36.18°
#   Frase 19: curvatura espacial média = 39.63°
#   Frase 20: curvatura espacial média = 38.41°
#   Frase 21: curvatura espacial média = 43.43°
#   Frase 22: curvatura espacial média = 36.63°
#   Frase 23: curvatura espacial média = 45.76°
#   Frase 24: curvatura espacial média = 35.62°
#   Frase 25: curvatura espacial média = 48.00°
#   Frase 26: curvatura espacial média = 40.08°
#   Frase 27: curvatura espacial média = 41.28°
#   Frase 28: curvatura espacial média = 40.52°
#   Frase 29: curvatura espacial média = 39.10°
#   Frase 30: curvatura espacial média = 41.99°
#   Frase 31: curvatura espacial média = 36.63°
#   Frase 32: curvatura espacial média = 43.56°
#   Frase 33: curvatura espacial média = 37.75°
#   Frase 34: curvatura espacial média = 37.75°
#   Frase 35: curvatura espacial média = 48.16°
#   Frase 36: curvatura espacial média = 39.79°
#   Frase 37: curvatura espacial média = 39.51°
#   Frase 38: curvatura espacial média = 39.65°
#   Frase 39: curvatura espacial média = 39.65°
#   Frase 40: curvatura espacial média = 38.41°
#   Frase 41: curvatura espacial média = 44.65°
#   Frase 42: curvatura espacial média = 45.12°
#   Frase 43: curvatura espacial média = 48.16°
#   Frase 44: curvatura espacial média = 41.99°
#   Frase 45: curvatura espacial média = 35.12°
#   Frase 46: curvatura espacial média = 45.18°
#   Frase 47: curvatura espacial média = 39.51°
#   Frase 48: curvatura espacial média = 36.63°
#   Frase 49: curvatura espacial média = 38.86°
#   Frase 50: curvatura espacial média = 40.69°
#   Frase 51: curvatura espacial média = 45.12°
#   Frase 52: curvatura espacial média = 41.28°
#   Frase 53: curvatura espacial média = 39.76°
#   Frase 54: curvatura espacial média = 35.12°
#   Frase 55: curvatura espacial média = 40.52°
#   Frase 56: curvatura espacial média = 38.86°
# Camada 12:
#   Frase 0: curvatura espacial média = 51.50°
#   Frase 1: curvatura espacial média = 61.69°
#   Frase 2: curvatura espacial média = 51.50°
#   Frase 3: curvatura espacial média = 60.77°
#   Frase 4: curvatura espacial média = 53.43°
#   Frase 5: curvatura espacial média = 59.44°
#   Frase 6: curvatura espacial média = 47.78°
#   Frase 7: curvatura espacial média = 54.79°
#   Frase 8: curvatura espacial média = 47.78°
#   Frase 9: curvatura espacial média = 53.50°
#   Frase 10: curvatura espacial média = 61.69°
#   Frase 11: curvatura espacial média = 59.44°
#   Frase 12: curvatura espacial média = 53.72°
#   Frase 13: curvatura espacial média = 53.96°
#   Frase 14: curvatura espacial média = 48.76°
#   Frase 15: curvatura espacial média = 53.50°
#   Frase 16: curvatura espacial média = 54.79°
#   Frase 17: curvatura espacial média = 54.74°
#   Frase 18: curvatura espacial média = 48.59°
#   Frase 19: curvatura espacial média = 54.74°
#   Frase 20: curvatura espacial média = 51.50°
#   Frase 21: curvatura espacial média = 56.37°
#   Frase 22: curvatura espacial média = 46.93°
#   Frase 23: curvatura espacial média = 60.77°
#   Frase 24: curvatura espacial média = 48.76°
#   Frase 25: curvatura espacial média = 61.69°
#   Frase 26: curvatura espacial média = 53.72°
#   Frase 27: curvatura espacial média = 53.50°
#   Frase 28: curvatura espacial média = 53.94°
#   Frase 29: curvatura espacial média = 53.43°
#   Frase 30: curvatura espacial média = 55.96°
#   Frase 31: curvatura espacial média = 46.93°
#   Frase 32: curvatura espacial média = 54.79°
#   Frase 33: curvatura espacial média = 47.78°
#   Frase 34: curvatura espacial média = 47.78°
#   Frase 35: curvatura espacial média = 63.90°
#   Frase 36: curvatura espacial média = 54.70°
#   Frase 37: curvatura espacial média = 52.83°
#   Frase 38: curvatura espacial média = 54.16°
#   Frase 39: curvatura espacial média = 54.16°
#   Frase 40: curvatura espacial média = 51.50°
#   Frase 41: curvatura espacial média = 56.75°
#   Frase 42: curvatura espacial média = 56.86°
#   Frase 43: curvatura espacial média = 63.90°
#   Frase 44: curvatura espacial média = 55.96°
#   Frase 45: curvatura espacial média = 45.24°
#   Frase 46: curvatura espacial média = 60.46°
#   Frase 47: curvatura espacial média = 52.83°
#   Frase 48: curvatura espacial média = 46.93°
#   Frase 49: curvatura espacial média = 50.31°
#   Frase 50: curvatura espacial média = 50.25°
#   Frase 51: curvatura espacial média = 56.86°
#   Frase 52: curvatura espacial média = 53.50°
#   Frase 53: curvatura espacial média = 53.96°
#   Frase 54: curvatura espacial média = 45.24°
#   Frase 55: curvatura espacial média = 53.94°
#   Frase 56: curvatura espacial média = 50.31°

# %%
# Lista geral para guardar os ângulos individuais
# Estrutura: [camada][frase][parDeEmbeddings]
angulosIndividuaisPorCamada = []

# Percorre cada camada
for iCamada in range(nCamadas):
    angulosPorFrase = []

    # Percorre cada frase
    for iFrase in range(nFrases):
        angulosEmbeddings = []

        # Percorre pares de embeddings consecutivos
        for iEmbedding in range(nEmbeddings - 1):
            v1 = embeddingsPorCamada[iCamada][iFrase][iEmbedding]
            v2 = embeddingsPorCamada[iCamada][iFrase][iEmbedding + 1]

            angulo = anguloEntre(v1, v2)  # ângulo entre dois embeddings consecutivos
            angulosEmbeddings.append(angulo.item())

        angulosPorFrase.append(angulosEmbeddings)  # salva todos os ângulos dessa frase

    angulosIndividuaisPorCamada.append(angulosPorFrase)  # salva os ângulos da camada

# %%
for iCamada, frases in enumerate(angulosIndividuaisPorCamada):
    print(f"\nCamada {iCamada}:")
    for iFrase, angulos in enumerate(frases):
        print(f"  Frase {iFrase}:")
        for i, angulo in enumerate(angulos):
            print(f"    Embedding {i} → {i+1}: {angulo:.2f}°")
# Out:
# Camada 0:
#   Frase 0:
#     Embedding 0 → 1: 90.98°
#     Embedding 1 → 2: 86.95°
#     Embedding 2 → 3: 82.10°
#     Embedding 3 → 4: 83.60°
#     Embedding 4 → 5: 87.52°
#     Embedding 5 → 6: 80.24°
#     Embedding 6 → 7: 86.16°
#     Embedding 7 → 8: 84.99°
#     Embedding 8 → 9: 82.28°
#     Embedding 9 → 10: 80.43°
#     Embedding 10 → 11: 81.96°
#     Embedding 11 → 12: 84.11°
#     Embedding 12 → 13: 88.62°
#     Embedding 13 → 14: 81.99°
#     Embedding 14 → 15: 85.39°
#     Embedding 15 → 16: 68.95°
#     Embedding 16 → 17: 81.88°
#     Embedding 17 → 18: 18.96°
#     Embedding 18 → 19: 18.83°
#     Embedding 19 → 20: 18.41°
#     Embedding 20 → 21: 18.65°
#     Embedding 21 → 22: 17.87°
#     Embedding 22 → 23: 18.44°
#   Frase 1:
#     Embedding 0 → 1: 89.01°
#     Embedding 1 → 2: 81.42°
#     Embedding 2 → 3: 88.33°
#     Embedding 3 → 4: 87.03°
#     Embedding 4 → 5: 84.60°
#     Embedding 5 → 6: 84.70°
#     Embedding 6 → 7: 85.60°
#     Embedding 7 → 8: 84.67°
#     Embedding 8 → 9: 89.13°
#     Embedding 9 → 10: 85.93°
#     Embedding 10 → 11: 83.54°
#     Embedding 11 → 12: 80.80°
#     Embedding 12 → 13: 86.74°
#     Embedding 13 → 14: 81.37°
#     Embedding 14 → 15: 85.53°
#     Embedding 15 → 16: 84.09°
#     Embedding 16 → 17: 82.79°
#     Embedding 17 → 18: 81.54°
#     Embedding 18 → 19: 83.06°
#     Embedding 19 → 20: 84.65°
#     Embedding 20 → 21: 69.38°
#     Embedding 21 → 22: 80.32°
#     Embedding 22 → 23: 18.44°
#   Frase 2:
#     Embedding 0 → 1: 90.98°
#     Embedding 1 → 2: 86.95°
#     Embedding 2 → 3: 82.10°
#     Embedding 3 → 4: 83.60°
#     Embedding 4 → 5: 87.52°
#     Embedding 5 → 6: 80.24°
#     Embedding 6 → 7: 86.16°
#     Embedding 7 → 8: 84.99°
#     Embedding 8 → 9: 82.28°
#     Embedding 9 → 10: 80.43°
#     Embedding 10 → 11: 81.96°
#     Embedding 11 → 12: 84.11°
#     Embedding 12 → 13: 88.62°
#     Embedding 13 → 14: 81.99°
#     Embedding 14 → 15: 85.39°
#     Embedding 15 → 16: 68.95°
#     Embedding 16 → 17: 81.88°
#     Embedding 17 → 18: 18.96°
#     Embedding 18 → 19: 18.83°
#     Embedding 19 → 20: 18.41°
#     Embedding 20 → 21: 18.65°
#     Embedding 21 → 22: 17.87°
#     Embedding 22 → 23: 18.44°
#   Frase 3:
#     Embedding 0 → 1: 88.87°
#     Embedding 1 → 2: 84.65°
#     Embedding 2 → 3: 87.01°
#     Embedding 3 → 4: 80.50°
#     Embedding 4 → 5: 81.58°
#     Embedding 5 → 6: 87.74°
#     Embedding 6 → 7: 85.56°
#     Embedding 7 → 8: 83.74°
#     Embedding 8 → 9: 82.13°
#     Embedding 9 → 10: 84.02°
#     Embedding 10 → 11: 88.78°
#     Embedding 11 → 12: 87.97°
#     Embedding 12 → 13: 84.83°
#     Embedding 13 → 14: 82.99°
#     Embedding 14 → 15: 85.48°
#     Embedding 15 → 16: 83.39°
#     Embedding 16 → 17: 85.04°
#     Embedding 17 → 18: 69.73°
#     Embedding 18 → 19: 80.73°
#     Embedding 19 → 20: 18.41°
#     Embedding 20 → 21: 18.65°
#     Embedding 21 → 22: 17.87°
#     Embedding 22 → 23: 18.44°
#   Frase 4:
#     Embedding 0 → 1: 90.77°
#     Embedding 1 → 2: 82.77°
#     Embedding 2 → 3: 83.34°
#     Embedding 3 → 4: 84.81°
#     Embedding 4 → 5: 86.49°
#     Embedding 5 → 6: 87.26°
#     Embedding 6 → 7: 75.42°
#     Embedding 7 → 8: 85.45°
#     Embedding 8 → 9: 87.33°
#     Embedding 9 → 10: 87.63°
#     Embedding 10 → 11: 84.57°
#     Embedding 11 → 12: 86.39°
#     Embedding 12 → 13: 79.24°
#     Embedding 13 → 14: 85.25°
#     Embedding 14 → 15: 69.01°
#     Embedding 15 → 16: 81.02°
#     Embedding 16 → 17: 19.23°
#     Embedding 17 → 18: 18.96°
#     Embedding 18 → 19: 18.83°
#     Embedding 19 → 20: 18.41°
#     Embedding 20 → 21: 18.65°
#     Embedding 21 → 22: 17.87°
#     Embedding 22 → 23: 18.44°
#   Frase 5:
#     Embedding 0 → 1: 88.50°
#     Embedding 1 → 2: 85.65°
#     Embedding 2 → 3: 89.44°
#     Embedding 3 → 4: 80.50°
#     Embedding 4 → 5: 84.02°
#     Embedding 5 → 6: 85.63°
#     Embedding 6 → 7: 85.90°
#     Embedding 7 → 8: 80.28°
#     Embedding 8 → 9: 79.17°
#     Embedding 9 → 10: 75.99°
#     Embedding 10 → 11: 84.58°
#     Embedding 11 → 12: 82.01°
#     Embedding 12 → 13: 83.58°
#     Embedding 13 → 14: 86.32°
#     Embedding 14 → 15: 84.69°
#     Embedding 15 → 16: 84.83°
#     Embedding 16 → 17: 83.64°
#     Embedding 17 → 18: 88.16°
#     Embedding 18 → 19: 88.17°
#     Embedding 19 → 20: 68.93°
#     Embedding 20 → 21: 82.34°
#     Embedding 21 → 22: 17.87°
#     Embedding 22 → 23: 18.44°
#   Frase 6:
#     Embedding 0 → 1: 89.28°
#     Embedding 1 → 2: 86.35°
#     Embedding 2 → 3: 87.15°
#     Embedding 3 → 4: 84.75°
#     Embedding 4 → 5: 73.74°
#     Embedding 5 → 6: 88.53°
#     Embedding 6 → 7: 83.68°
#     Embedding 7 → 8: 80.71°
#     Embedding 8 → 9: 86.35°
#     Embedding 9 → 10: 81.85°
#     Embedding 10 → 11: 70.25°
#     Embedding 11 → 12: 81.99°
#     Embedding 12 → 13: 18.48°
#     Embedding 13 → 14: 18.98°
#     Embedding 14 → 15: 18.64°
#     Embedding 15 → 16: 19.24°
#     Embedding 16 → 17: 19.23°
#     Embedding 17 → 18: 18.96°
#     Embedding 18 → 19: 18.83°
#     Embedding 19 → 20: 18.41°
#     Embedding 20 → 21: 18.65°
#     Embedding 21 → 22: 17.87°
#     Embedding 22 → 23: 18.44°
#   Frase 7:
#     Embedding 0 → 1: 91.27°
#     Embedding 1 → 2: 88.00°
#     Embedding 2 → 3: 88.13°
#     Embedding 3 → 4: 85.90°
#     Embedding 4 → 5: 84.80°
#     Embedding 5 → 6: 86.27°
#     Embedding 6 → 7: 86.37°
#     Embedding 7 → 8: 84.03°
#     Embedding 8 → 9: 77.34°
#     Embedding 9 → 10: 83.86°
#     Embedding 10 → 11: 87.87°
#     Embedding 11 → 12: 83.53°
#     Embedding 12 → 13: 86.27°
#     Embedding 13 → 14: 15.56°
#     Embedding 14 → 15: 80.88°
#     Embedding 15 → 16: 84.95°
#     Embedding 16 → 17: 69.43°
#     Embedding 17 → 18: 82.34°
#     Embedding 18 → 19: 18.83°
#     Embedding 19 → 20: 18.41°
#     Embedding 20 → 21: 18.65°
#     Embedding 21 → 22: 17.87°
#     Embedding 22 → 23: 18.44°
#   Frase 8:
#     Embedding 0 → 1: 89.28°
#     Embedding 1 → 2: 86.35°
#     Embedding 2 → 3: 87.15°
#     Embedding 3 → 4: 84.75°
#     Embedding 4 → 5: 73.74°
#     Embedding 5 → 6: 88.53°
#     Embedding 6 → 7: 83.68°
#     Embedding 7 → 8: 80.71°
#     Embedding 8 → 9: 86.35°
#     Embedding 9 → 10: 81.85°
#     Embedding 10 → 11: 70.25°
#     Embedding 11 → 12: 81.99°
#     Embedding 12 → 13: 18.48°
#     Embedding 13 → 14: 18.98°
#     Embedding 14 → 15: 18.64°
#     Embedding 15 → 16: 19.24°
#     Embedding 16 → 17: 19.23°
#     Embedding 17 → 18: 18.96°
#     Embedding 18 → 19: 18.83°
#     Embedding 19 → 20: 18.41°
#     Embedding 20 → 21: 18.65°
#     Embedding 21 → 22: 17.87°
#     Embedding 22 → 23: 18.44°
#   Frase 9:
#     Embedding 0 → 1: 91.49°
#     Embedding 1 → 2: 81.10°
#     Embedding 2 → 3: 84.45°
#     Embedding 3 → 4: 84.82°
#     Embedding 4 → 5: 75.57°
#     Embedding 5 → 6: 81.34°
#     Embedding 6 → 7: 83.41°
#     Embedding 7 → 8: 90.91°
#     Embedding 8 → 9: 84.56°
#     Embedding 9 → 10: 85.93°
#     Embedding 10 → 11: 82.23°
#     Embedding 11 → 12: 85.22°
#     Embedding 12 → 13: 80.82°
#     Embedding 13 → 14: 86.59°
#     Embedding 14 → 15: 86.48°
#     Embedding 15 → 16: 88.54°
#     Embedding 16 → 17: 87.57°
#     Embedding 17 → 18: 69.73°
#     Embedding 18 → 19: 80.73°
#     Embedding 19 → 20: 18.41°
#     Embedding 20 → 21: 18.65°
#     Embedding 21 → 22: 17.87°
#     Embedding 22 → 23: 18.44°
#   Frase 10:
#     Embedding 0 → 1: 89.01°
#     Embedding 1 → 2: 81.42°
#     Embedding 2 → 3: 88.33°
#     Embedding 3 → 4: 87.03°
#     Embedding 4 → 5: 84.60°
#     Embedding 5 → 6: 84.70°
#     Embedding 6 → 7: 85.60°
#     Embedding 7 → 8: 84.67°
#     Embedding 8 → 9: 89.13°
#     Embedding 9 → 10: 85.93°
#     Embedding 10 → 11: 83.54°
#     Embedding 11 → 12: 80.80°
#     Embedding 12 → 13: 86.74°
#     Embedding 13 → 14: 81.37°
#     Embedding 14 → 15: 85.53°
#     Embedding 15 → 16: 84.09°
#     Embedding 16 → 17: 82.79°
#     Embedding 17 → 18: 81.54°
#     Embedding 18 → 19: 83.06°
#     Embedding 19 → 20: 84.65°
#     Embedding 20 → 21: 69.38°
#     Embedding 21 → 22: 80.32°
#     Embedding 22 → 23: 18.44°
#   Frase 11:
#     Embedding 0 → 1: 88.50°
#     Embedding 1 → 2: 85.65°
#     Embedding 2 → 3: 89.44°
#     Embedding 3 → 4: 80.50°
#     Embedding 4 → 5: 84.02°
#     Embedding 5 → 6: 85.63°
#     Embedding 6 → 7: 85.90°
#     Embedding 7 → 8: 80.28°
#     Embedding 8 → 9: 79.17°
#     Embedding 9 → 10: 75.99°
#     Embedding 10 → 11: 84.58°
#     Embedding 11 → 12: 82.01°
#     Embedding 12 → 13: 83.58°
#     Embedding 13 → 14: 86.32°
#     Embedding 14 → 15: 84.69°
#     Embedding 15 → 16: 84.83°
#     Embedding 16 → 17: 83.64°
#     Embedding 17 → 18: 88.16°
#     Embedding 18 → 19: 88.17°
#     Embedding 19 → 20: 68.93°
#     Embedding 20 → 21: 82.34°
#     Embedding 21 → 22: 17.87°
#     Embedding 22 → 23: 18.44°
#   Frase 12:
#     Embedding 0 → 1: 89.58°
#     Embedding 1 → 2: 83.72°
#     Embedding 2 → 3: 87.12°
#     Embedding 3 → 4: 84.76°
#     Embedding 4 → 5: 86.10°
#     Embedding 5 → 6: 79.05°
#     Embedding 6 → 7: 83.88°
#     Embedding 7 → 8: 85.33°
#     Embedding 8 → 9: 85.78°
#     Embedding 9 → 10: 86.94°
#     Embedding 10 → 11: 81.85°
#     Embedding 11 → 12: 86.14°
#     Embedding 12 → 13: 69.76°
#     Embedding 13 → 14: 81.72°
#     Embedding 14 → 15: 18.64°
#     Embedding 15 → 16: 19.24°
#     Embedding 16 → 17: 19.23°
#     Embedding 17 → 18: 18.96°
#     Embedding 18 → 19: 18.83°
#     Embedding 19 → 20: 18.41°
#     Embedding 20 → 21: 18.65°
#     Embedding 21 → 22: 17.87°
#     Embedding 22 → 23: 18.44°
#   Frase 13:
#     Embedding 0 → 1: 91.24°
#     Embedding 1 → 2: 86.90°
#     Embedding 2 → 3: 82.82°
#     Embedding 3 → 4: 84.92°
#     Embedding 4 → 5: 79.99°
#     Embedding 5 → 6: 86.98°
#     Embedding 6 → 7: 90.68°
#     Embedding 7 → 8: 87.01°
#     Embedding 8 → 9: 85.80°
#     Embedding 9 → 10: 85.05°
#     Embedding 10 → 11: 87.35°
#     Embedding 11 → 12: 82.05°
#     Embedding 12 → 13: 85.80°
#     Embedding 13 → 14: 69.74°
#     Embedding 14 → 15: 81.73°
#     Embedding 15 → 16: 19.24°
#     Embedding 16 → 17: 19.23°
#     Embedding 17 → 18: 18.96°
#     Embedding 18 → 19: 18.83°
#     Embedding 19 → 20: 18.41°
#     Embedding 20 → 21: 18.65°
#     Embedding 21 → 22: 17.87°
#     Embedding 22 → 23: 18.44°
#   Frase 14:
#     Embedding 0 → 1: 90.54°
#     Embedding 1 → 2: 82.53°
#     Embedding 2 → 3: 81.73°
#     Embedding 3 → 4: 85.14°
#     Embedding 4 → 5: 82.68°
#     Embedding 5 → 6: 84.82°
#     Embedding 6 → 7: 83.76°
#     Embedding 7 → 8: 87.01°
#     Embedding 8 → 9: 88.66°
#     Embedding 9 → 10: 82.79°
#     Embedding 10 → 11: 83.90°
#     Embedding 11 → 12: 84.10°
#     Embedding 12 → 13: 69.76°
#     Embedding 13 → 14: 81.72°
#     Embedding 14 → 15: 18.64°
#     Embedding 15 → 16: 19.24°
#     Embedding 16 → 17: 19.23°
#     Embedding 17 → 18: 18.96°
#     Embedding 18 → 19: 18.83°
#     Embedding 19 → 20: 18.41°
#     Embedding 20 → 21: 18.65°
#     Embedding 21 → 22: 17.87°
#     Embedding 22 → 23: 18.44°
#   Frase 15:
#     Embedding 0 → 1: 91.49°
#     Embedding 1 → 2: 81.10°
#     Embedding 2 → 3: 84.45°
#     Embedding 3 → 4: 84.82°
#     Embedding 4 → 5: 75.57°
#     Embedding 5 → 6: 81.34°
#     Embedding 6 → 7: 83.41°
#     Embedding 7 → 8: 90.91°
#     Embedding 8 → 9: 84.56°
#     Embedding 9 → 10: 85.93°
#     Embedding 10 → 11: 82.23°
#     Embedding 11 → 12: 85.22°
#     Embedding 12 → 13: 80.82°
#     Embedding 13 → 14: 86.59°
#     Embedding 14 → 15: 86.48°
#     Embedding 15 → 16: 88.54°
#     Embedding 16 → 17: 87.57°
#     Embedding 17 → 18: 69.73°
#     Embedding 18 → 19: 80.73°
#     Embedding 19 → 20: 18.41°
#     Embedding 20 → 21: 18.65°
#     Embedding 21 → 22: 17.87°
#     Embedding 22 → 23: 18.44°
#   Frase 16:
#     Embedding 0 → 1: 91.27°
#     Embedding 1 → 2: 88.00°
#     Embedding 2 → 3: 88.13°
#     Embedding 3 → 4: 85.90°
#     Embedding 4 → 5: 84.80°
#     Embedding 5 → 6: 86.27°
#     Embedding 6 → 7: 86.37°
#     Embedding 7 → 8: 84.03°
#     Embedding 8 → 9: 77.34°
#     Embedding 9 → 10: 83.86°
#     Embedding 10 → 11: 87.87°
#     Embedding 11 → 12: 83.53°
#     Embedding 12 → 13: 86.27°
#     Embedding 13 → 14: 15.56°
#     Embedding 14 → 15: 80.88°
#     Embedding 15 → 16: 84.95°
#     Embedding 16 → 17: 69.43°
#     Embedding 17 → 18: 82.34°
#     Embedding 18 → 19: 18.83°
#     Embedding 19 → 20: 18.41°
#     Embedding 20 → 21: 18.65°
#     Embedding 21 → 22: 17.87°
#     Embedding 22 → 23: 18.44°
#   Frase 17:
#     Embedding 0 → 1: 89.86°
#     Embedding 1 → 2: 79.72°
#     Embedding 2 → 3: 85.48°
#     Embedding 3 → 4: 82.33°
#     Embedding 4 → 5: 85.11°
#     Embedding 5 → 6: 84.94°
#     Embedding 6 → 7: 89.31°
#     Embedding 7 → 8: 86.00°
#     Embedding 8 → 9: 86.91°
#     Embedding 9 → 10: 80.49°
#     Embedding 10 → 11: 86.70°
#     Embedding 11 → 12: 79.32°
#     Embedding 12 → 13: 86.66°
#     Embedding 13 → 14: 69.74°
#     Embedding 14 → 15: 81.73°
#     Embedding 15 → 16: 19.24°
#     Embedding 16 → 17: 19.23°
#     Embedding 17 → 18: 18.96°
#     Embedding 18 → 19: 18.83°
#     Embedding 19 → 20: 18.41°
#     Embedding 20 → 21: 18.65°
#     Embedding 21 → 22: 17.87°
#     Embedding 22 → 23: 18.44°
#   Frase 18:
#     Embedding 0 → 1: 89.93°
#     Embedding 1 → 2: 85.45°
#     Embedding 2 → 3: 82.66°
#     Embedding 3 → 4: 83.57°
#     Embedding 4 → 5: 87.79°
#     Embedding 5 → 6: 84.87°
#     Embedding 6 → 7: 82.84°
#     Embedding 7 → 8: 90.23°
#     Embedding 8 → 9: 82.23°
#     Embedding 9 → 10: 85.03°
#     Embedding 10 → 11: 70.25°
#     Embedding 11 → 12: 81.99°
#     Embedding 12 → 13: 18.48°
#     Embedding 13 → 14: 18.98°
#     Embedding 14 → 15: 18.64°
#     Embedding 15 → 16: 19.24°
#     Embedding 16 → 17: 19.23°
#     Embedding 17 → 18: 18.96°
#     Embedding 18 → 19: 18.83°
#     Embedding 19 → 20: 18.41°
#     Embedding 20 → 21: 18.65°
#     Embedding 21 → 22: 17.87°
#     Embedding 22 → 23: 18.44°
#   Frase 19:
#     Embedding 0 → 1: 89.86°
#     Embedding 1 → 2: 79.72°
#     Embedding 2 → 3: 85.48°
#     Embedding 3 → 4: 82.33°
#     Embedding 4 → 5: 85.11°
#     Embedding 5 → 6: 84.94°
#     Embedding 6 → 7: 89.31°
#     Embedding 7 → 8: 86.00°
#     Embedding 8 → 9: 86.91°
#     Embedding 9 → 10: 80.49°
#     Embedding 10 → 11: 86.70°
#     Embedding 11 → 12: 79.32°
#     Embedding 12 → 13: 86.66°
#     Embedding 13 → 14: 69.74°
#     Embedding 14 → 15: 81.73°
#     Embedding 15 → 16: 19.24°
#     Embedding 16 → 17: 19.23°
#     Embedding 17 → 18: 18.96°
#     Embedding 18 → 19: 18.83°
#     Embedding 19 → 20: 18.41°
#     Embedding 20 → 21: 18.65°
#     Embedding 21 → 22: 17.87°
#     Embedding 22 → 23: 18.44°
#   Frase 20:
#     Embedding 0 → 1: 90.98°
#     Embedding 1 → 2: 86.95°
#     Embedding 2 → 3: 82.10°
#     Embedding 3 → 4: 83.60°
#     Embedding 4 → 5: 87.52°
#     Embedding 5 → 6: 80.24°
#     Embedding 6 → 7: 86.16°
#     Embedding 7 → 8: 84.99°
#     Embedding 8 → 9: 82.28°
#     Embedding 9 → 10: 80.43°
#     Embedding 10 → 11: 81.96°
#     Embedding 11 → 12: 84.11°
#     Embedding 12 → 13: 88.62°
#     Embedding 13 → 14: 81.99°
#     Embedding 14 → 15: 85.39°
#     Embedding 15 → 16: 68.95°
#     Embedding 16 → 17: 81.88°
#     Embedding 17 → 18: 18.96°
#     Embedding 18 → 19: 18.83°
#     Embedding 19 → 20: 18.41°
#     Embedding 20 → 21: 18.65°
#     Embedding 21 → 22: 17.87°
#     Embedding 22 → 23: 18.44°
#   Frase 21:
#     Embedding 0 → 1: 90.28°
#     Embedding 1 → 2: 85.22°
#     Embedding 2 → 3: 78.22°
#     Embedding 3 → 4: 85.95°
#     Embedding 4 → 5: 87.98°
#     Embedding 5 → 6: 79.79°
#     Embedding 6 → 7: 82.28°
#     Embedding 7 → 8: 87.22°
#     Embedding 8 → 9: 87.15°
#     Embedding 9 → 10: 84.35°
#     Embedding 10 → 11: 82.50°
#     Embedding 11 → 12: 84.95°
#     Embedding 12 → 13: 88.01°
#     Embedding 13 → 14: 84.89°
#     Embedding 14 → 15: 85.49°
#     Embedding 15 → 16: 68.95°
#     Embedding 16 → 17: 81.88°
#     Embedding 17 → 18: 18.96°
#     Embedding 18 → 19: 18.83°
#     Embedding 19 → 20: 18.41°
#     Embedding 20 → 21: 18.65°
#     Embedding 21 → 22: 17.87°
#     Embedding 22 → 23: 18.44°
#   Frase 22:
#     Embedding 0 → 1: 88.24°
#     Embedding 1 → 2: 86.53°
#     Embedding 2 → 3: 91.08°
#     Embedding 3 → 4: 89.97°
#     Embedding 4 → 5: 85.56°
#     Embedding 5 → 6: 87.08°
#     Embedding 6 → 7: 83.61°
#     Embedding 7 → 8: 84.25°
#     Embedding 8 → 9: 87.26°
#     Embedding 9 → 10: 69.65°
#     Embedding 10 → 11: 82.19°
#     Embedding 11 → 12: 18.07°
#     Embedding 12 → 13: 18.48°
#     Embedding 13 → 14: 18.98°
#     Embedding 14 → 15: 18.64°
#     Embedding 15 → 16: 19.24°
#     Embedding 16 → 17: 19.23°
#     Embedding 17 → 18: 18.96°
#     Embedding 18 → 19: 18.83°
#     Embedding 19 → 20: 18.41°
#     Embedding 20 → 21: 18.65°
#     Embedding 21 → 22: 17.87°
#     Embedding 22 → 23: 18.44°
#   Frase 23:
#     Embedding 0 → 1: 88.87°
#     Embedding 1 → 2: 84.65°
#     Embedding 2 → 3: 87.01°
#     Embedding 3 → 4: 80.50°
#     Embedding 4 → 5: 81.58°
#     Embedding 5 → 6: 87.74°
#     Embedding 6 → 7: 85.56°
#     Embedding 7 → 8: 83.74°
#     Embedding 8 → 9: 82.13°
#     Embedding 9 → 10: 84.02°
#     Embedding 10 → 11: 88.78°
#     Embedding 11 → 12: 87.97°
#     Embedding 12 → 13: 84.83°
#     Embedding 13 → 14: 82.99°
#     Embedding 14 → 15: 85.48°
#     Embedding 15 → 16: 83.39°
#     Embedding 16 → 17: 85.04°
#     Embedding 17 → 18: 69.73°
#     Embedding 18 → 19: 80.73°
#     Embedding 19 → 20: 18.41°
#     Embedding 20 → 21: 18.65°
#     Embedding 21 → 22: 17.87°
#     Embedding 22 → 23: 18.44°
#   Frase 24:
#     Embedding 0 → 1: 90.54°
#     Embedding 1 → 2: 82.53°
#     Embedding 2 → 3: 81.73°
#     Embedding 3 → 4: 85.14°
#     Embedding 4 → 5: 82.68°
#     Embedding 5 → 6: 84.82°
#     Embedding 6 → 7: 83.76°
#     Embedding 7 → 8: 87.01°
#     Embedding 8 → 9: 88.66°
#     Embedding 9 → 10: 82.79°
#     Embedding 10 → 11: 83.90°
#     Embedding 11 → 12: 84.10°
#     Embedding 12 → 13: 69.76°
#     Embedding 13 → 14: 81.72°
#     Embedding 14 → 15: 18.64°
#     Embedding 15 → 16: 19.24°
#     Embedding 16 → 17: 19.23°
#     Embedding 17 → 18: 18.96°
#     Embedding 18 → 19: 18.83°
#     Embedding 19 → 20: 18.41°
#     Embedding 20 → 21: 18.65°
#     Embedding 21 → 22: 17.87°
#     Embedding 22 → 23: 18.44°
#   Frase 25:
#     Embedding 0 → 1: 89.01°
#     Embedding 1 → 2: 81.42°
#     Embedding 2 → 3: 88.33°
#     Embedding 3 → 4: 87.03°
#     Embedding 4 → 5: 84.60°
#     Embedding 5 → 6: 84.70°
#     Embedding 6 → 7: 85.60°
#     Embedding 7 → 8: 84.67°
#     Embedding 8 → 9: 89.13°
#     Embedding 9 → 10: 85.93°
#     Embedding 10 → 11: 83.54°
#     Embedding 11 → 12: 80.80°
#     Embedding 12 → 13: 86.74°
#     Embedding 13 → 14: 81.37°
#     Embedding 14 → 15: 85.53°
#     Embedding 15 → 16: 84.09°
#     Embedding 16 → 17: 82.79°
#     Embedding 17 → 18: 81.54°
#     Embedding 18 → 19: 83.06°
#     Embedding 19 → 20: 84.65°
#     Embedding 20 → 21: 69.38°
#     Embedding 21 → 22: 80.32°
#     Embedding 22 → 23: 18.44°
#   Frase 26:
#     Embedding 0 → 1: 89.58°
#     Embedding 1 → 2: 83.72°
#     Embedding 2 → 3: 87.12°
#     Embedding 3 → 4: 84.76°
#     Embedding 4 → 5: 86.10°
#     Embedding 5 → 6: 79.05°
#     Embedding 6 → 7: 83.88°
#     Embedding 7 → 8: 85.33°
#     Embedding 8 → 9: 85.78°
#     Embedding 9 → 10: 86.94°
#     Embedding 10 → 11: 81.85°
#     Embedding 11 → 12: 86.14°
#     Embedding 12 → 13: 69.76°
#     Embedding 13 → 14: 81.72°
#     Embedding 14 → 15: 18.64°
#     Embedding 15 → 16: 19.24°
#     Embedding 16 → 17: 19.23°
#     Embedding 17 → 18: 18.96°
#     Embedding 18 → 19: 18.83°
#     Embedding 19 → 20: 18.41°
#     Embedding 20 → 21: 18.65°
#     Embedding 21 → 22: 17.87°
#     Embedding 22 → 23: 18.44°
#   Frase 27:
#     Embedding 0 → 1: 91.49°
#     Embedding 1 → 2: 81.10°
#     Embedding 2 → 3: 84.45°
#     Embedding 3 → 4: 84.82°
#     Embedding 4 → 5: 75.57°
#     Embedding 5 → 6: 81.34°
#     Embedding 6 → 7: 83.41°
#     Embedding 7 → 8: 90.91°
#     Embedding 8 → 9: 84.56°
#     Embedding 9 → 10: 85.93°
#     Embedding 10 → 11: 82.23°
#     Embedding 11 → 12: 85.22°
#     Embedding 12 → 13: 80.82°
#     Embedding 13 → 14: 86.59°
#     Embedding 14 → 15: 86.48°
#     Embedding 15 → 16: 88.54°
#     Embedding 16 → 17: 87.57°
#     Embedding 17 → 18: 69.73°
#     Embedding 18 → 19: 80.73°
#     Embedding 19 → 20: 18.41°
#     Embedding 20 → 21: 18.65°
#     Embedding 21 → 22: 17.87°
#     Embedding 22 → 23: 18.44°
#   Frase 28:
#     Embedding 0 → 1: 89.32°
#     Embedding 1 → 2: 86.55°
#     Embedding 2 → 3: 84.64°
#     Embedding 3 → 4: 79.77°
#     Embedding 4 → 5: 85.61°
#     Embedding 5 → 6: 83.72°
#     Embedding 6 → 7: 76.59°
#     Embedding 7 → 8: 84.75°
#     Embedding 8 → 9: 86.22°
#     Embedding 9 → 10: 81.90°
#     Embedding 10 → 11: 82.88°
#     Embedding 11 → 12: 83.67°
#     Embedding 12 → 13: 77.05°
#     Embedding 13 → 14: 81.72°
#     Embedding 14 → 15: 18.64°
#     Embedding 15 → 16: 19.24°
#     Embedding 16 → 17: 19.23°
#     Embedding 17 → 18: 18.96°
#     Embedding 18 → 19: 18.83°
#     Embedding 19 → 20: 18.41°
#     Embedding 20 → 21: 18.65°
#     Embedding 21 → 22: 17.87°
#     Embedding 22 → 23: 18.44°
#   Frase 29:
#     Embedding 0 → 1: 90.77°
#     Embedding 1 → 2: 82.77°
#     Embedding 2 → 3: 83.34°
#     Embedding 3 → 4: 84.81°
#     Embedding 4 → 5: 86.49°
#     Embedding 5 → 6: 87.26°
#     Embedding 6 → 7: 75.42°
#     Embedding 7 → 8: 85.45°
#     Embedding 8 → 9: 87.33°
#     Embedding 9 → 10: 87.63°
#     Embedding 10 → 11: 84.57°
#     Embedding 11 → 12: 86.39°
#     Embedding 12 → 13: 79.24°
#     Embedding 13 → 14: 85.25°
#     Embedding 14 → 15: 69.01°
#     Embedding 15 → 16: 81.02°
#     Embedding 16 → 17: 19.23°
#     Embedding 17 → 18: 18.96°
#     Embedding 18 → 19: 18.83°
#     Embedding 19 → 20: 18.41°
#     Embedding 20 → 21: 18.65°
#     Embedding 21 → 22: 17.87°
#     Embedding 22 → 23: 18.44°
#   Frase 30:
#     Embedding 0 → 1: 89.75°
#     Embedding 1 → 2: 84.91°
#     Embedding 2 → 3: 84.16°
#     Embedding 3 → 4: 86.92°
#     Embedding 4 → 5: 82.80°
#     Embedding 5 → 6: 84.43°
#     Embedding 6 → 7: 84.25°
#     Embedding 7 → 8: 75.63°
#     Embedding 8 → 9: 80.87°
#     Embedding 9 → 10: 82.26°
#     Embedding 10 → 11: 83.56°
#     Embedding 11 → 12: 83.96°
#     Embedding 12 → 13: 83.10°
#     Embedding 13 → 14: 86.21°
#     Embedding 14 → 15: 69.01°
#     Embedding 15 → 16: 81.02°
#     Embedding 16 → 17: 19.23°
#     Embedding 17 → 18: 18.96°
#     Embedding 18 → 19: 18.83°
#     Embedding 19 → 20: 18.41°
#     Embedding 20 → 21: 18.65°
#     Embedding 21 → 22: 17.87°
#     Embedding 22 → 23: 18.44°
#   Frase 31:
#     Embedding 0 → 1: 88.24°
#     Embedding 1 → 2: 86.53°
#     Embedding 2 → 3: 91.08°
#     Embedding 3 → 4: 89.97°
#     Embedding 4 → 5: 85.56°
#     Embedding 5 → 6: 87.08°
#     Embedding 6 → 7: 83.61°
#     Embedding 7 → 8: 84.25°
#     Embedding 8 → 9: 87.26°
#     Embedding 9 → 10: 69.65°
#     Embedding 10 → 11: 82.19°
#     Embedding 11 → 12: 18.07°
#     Embedding 12 → 13: 18.48°
#     Embedding 13 → 14: 18.98°
#     Embedding 14 → 15: 18.64°
#     Embedding 15 → 16: 19.24°
#     Embedding 16 → 17: 19.23°
#     Embedding 17 → 18: 18.96°
#     Embedding 18 → 19: 18.83°
#     Embedding 19 → 20: 18.41°
#     Embedding 20 → 21: 18.65°
#     Embedding 21 → 22: 17.87°
#     Embedding 22 → 23: 18.44°
#   Frase 32:
#     Embedding 0 → 1: 91.27°
#     Embedding 1 → 2: 88.00°
#     Embedding 2 → 3: 88.13°
#     Embedding 3 → 4: 85.90°
#     Embedding 4 → 5: 84.80°
#     Embedding 5 → 6: 86.27°
#     Embedding 6 → 7: 86.37°
#     Embedding 7 → 8: 84.03°
#     Embedding 8 → 9: 77.34°
#     Embedding 9 → 10: 83.86°
#     Embedding 10 → 11: 87.87°
#     Embedding 11 → 12: 83.53°
#     Embedding 12 → 13: 86.27°
#     Embedding 13 → 14: 15.56°
#     Embedding 14 → 15: 80.88°
#     Embedding 15 → 16: 84.95°
#     Embedding 16 → 17: 69.43°
#     Embedding 17 → 18: 82.34°
#     Embedding 18 → 19: 18.83°
#     Embedding 19 → 20: 18.41°
#     Embedding 20 → 21: 18.65°
#     Embedding 21 → 22: 17.87°
#     Embedding 22 → 23: 18.44°
#   Frase 33:
#     Embedding 0 → 1: 89.28°
#     Embedding 1 → 2: 86.35°
#     Embedding 2 → 3: 87.15°
#     Embedding 3 → 4: 84.75°
#     Embedding 4 → 5: 73.74°
#     Embedding 5 → 6: 88.53°
#     Embedding 6 → 7: 83.68°
#     Embedding 7 → 8: 80.71°
#     Embedding 8 → 9: 86.35°
#     Embedding 9 → 10: 81.85°
#     Embedding 10 → 11: 70.25°
#     Embedding 11 → 12: 81.99°
#     Embedding 12 → 13: 18.48°
#     Embedding 13 → 14: 18.98°
#     Embedding 14 → 15: 18.64°
#     Embedding 15 → 16: 19.24°
#     Embedding 16 → 17: 19.23°
#     Embedding 17 → 18: 18.96°
#     Embedding 18 → 19: 18.83°
#     Embedding 19 → 20: 18.41°
#     Embedding 20 → 21: 18.65°
#     Embedding 21 → 22: 17.87°
#     Embedding 22 → 23: 18.44°
#   Frase 34:
#     Embedding 0 → 1: 89.28°
#     Embedding 1 → 2: 86.35°
#     Embedding 2 → 3: 87.15°
#     Embedding 3 → 4: 84.75°
#     Embedding 4 → 5: 73.74°
#     Embedding 5 → 6: 88.53°
#     Embedding 6 → 7: 83.68°
#     Embedding 7 → 8: 80.71°
#     Embedding 8 → 9: 86.35°
#     Embedding 9 → 10: 81.85°
#     Embedding 10 → 11: 70.25°
#     Embedding 11 → 12: 81.99°
#     Embedding 12 → 13: 18.48°
#     Embedding 13 → 14: 18.98°
#     Embedding 14 → 15: 18.64°
#     Embedding 15 → 16: 19.24°
#     Embedding 16 → 17: 19.23°
#     Embedding 17 → 18: 18.96°
#     Embedding 18 → 19: 18.83°
#     Embedding 19 → 20: 18.41°
#     Embedding 20 → 21: 18.65°
#     Embedding 21 → 22: 17.87°
#     Embedding 22 → 23: 18.44°
#   Frase 35:
#     Embedding 0 → 1: 89.94°
#     Embedding 1 → 2: 81.85°
#     Embedding 2 → 3: 83.45°
#     Embedding 3 → 4: 87.13°
#     Embedding 4 → 5: 88.77°
#     Embedding 5 → 6: 86.44°
#     Embedding 6 → 7: 79.72°
#     Embedding 7 → 8: 81.79°
#     Embedding 8 → 9: 86.94°
#     Embedding 9 → 10: 88.39°
#     Embedding 10 → 11: 86.74°
#     Embedding 11 → 12: 83.63°
#     Embedding 12 → 13: 84.55°
#     Embedding 13 → 14: 83.58°
#     Embedding 14 → 15: 84.86°
#     Embedding 15 → 16: 84.52°
#     Embedding 16 → 17: 85.37°
#     Embedding 17 → 18: 83.47°
#     Embedding 18 → 19: 83.50°
#     Embedding 19 → 20: 78.91°
#     Embedding 20 → 21: 84.56°
#     Embedding 21 → 22: 84.45°
#     Embedding 22 → 23: 68.85°
#   Frase 36:
#     Embedding 0 → 1: 88.56°
#     Embedding 1 → 2: 75.08°
#     Embedding 2 → 3: 89.67°
#     Embedding 3 → 4: 89.54°
#     Embedding 4 → 5: 86.56°
#     Embedding 5 → 6: 85.87°
#     Embedding 6 → 7: 86.27°
#     Embedding 7 → 8: 82.67°
#     Embedding 8 → 9: 85.94°
#     Embedding 9 → 10: 87.38°
#     Embedding 10 → 11: 85.52°
#     Embedding 11 → 12: 81.64°
#     Embedding 12 → 13: 69.76°
#     Embedding 13 → 14: 81.72°
#     Embedding 14 → 15: 18.64°
#     Embedding 15 → 16: 19.24°
#     Embedding 16 → 17: 19.23°
#     Embedding 17 → 18: 18.96°
#     Embedding 18 → 19: 18.83°
#     Embedding 19 → 20: 18.41°
#     Embedding 20 → 21: 18.65°
#     Embedding 21 → 22: 17.87°
#     Embedding 22 → 23: 18.44°
#   Frase 37:
#     Embedding 0 → 1: 90.59°
#     Embedding 1 → 2: 85.35°
#     Embedding 2 → 3: 81.92°
#     Embedding 3 → 4: 87.20°
#     Embedding 4 → 5: 86.80°
#     Embedding 5 → 6: 84.20°
#     Embedding 6 → 7: 87.32°
#     Embedding 7 → 8: 81.34°
#     Embedding 8 → 9: 84.68°
#     Embedding 9 → 10: 86.35°
#     Embedding 10 → 11: 78.72°
#     Embedding 11 → 12: 85.91°
#     Embedding 12 → 13: 86.98°
#     Embedding 13 → 14: 83.13°
#     Embedding 14 → 15: 87.61°
#     Embedding 15 → 16: 84.82°
#     Embedding 16 → 17: 69.43°
#     Embedding 17 → 18: 82.34°
#     Embedding 18 → 19: 18.83°
#     Embedding 19 → 20: 18.41°
#     Embedding 20 → 21: 18.65°
#     Embedding 21 → 22: 17.87°
#     Embedding 22 → 23: 18.44°
#   Frase 38:
#     Embedding 0 → 1: 88.67°
#     Embedding 1 → 2: 84.31°
#     Embedding 2 → 3: 79.92°
#     Embedding 3 → 4: 82.61°
#     Embedding 4 → 5: 81.36°
#     Embedding 5 → 6: 85.74°
#     Embedding 6 → 7: 87.60°
#     Embedding 7 → 8: 86.17°
#     Embedding 8 → 9: 85.29°
#     Embedding 9 → 10: 83.33°
#     Embedding 10 → 11: 81.98°
#     Embedding 11 → 12: 84.37°
#     Embedding 12 → 13: 69.76°
#     Embedding 13 → 14: 81.72°
#     Embedding 14 → 15: 18.64°
#     Embedding 15 → 16: 19.24°
#     Embedding 16 → 17: 19.23°
#     Embedding 17 → 18: 18.96°
#     Embedding 18 → 19: 18.83°
#     Embedding 19 → 20: 18.41°
#     Embedding 20 → 21: 18.65°
#     Embedding 21 → 22: 17.87°
#     Embedding 22 → 23: 18.44°
#   Frase 39:
#     Embedding 0 → 1: 88.67°
#     Embedding 1 → 2: 84.31°
#     Embedding 2 → 3: 79.92°
#     Embedding 3 → 4: 82.61°
#     Embedding 4 → 5: 81.36°
#     Embedding 5 → 6: 85.74°
#     Embedding 6 → 7: 87.60°
#     Embedding 7 → 8: 86.17°
#     Embedding 8 → 9: 85.29°
#     Embedding 9 → 10: 83.33°
#     Embedding 10 → 11: 81.98°
#     Embedding 11 → 12: 84.37°
#     Embedding 12 → 13: 69.76°
#     Embedding 13 → 14: 81.72°
#     Embedding 14 → 15: 18.64°
#     Embedding 15 → 16: 19.24°
#     Embedding 16 → 17: 19.23°
#     Embedding 17 → 18: 18.96°
#     Embedding 18 → 19: 18.83°
#     Embedding 19 → 20: 18.41°
#     Embedding 20 → 21: 18.65°
#     Embedding 21 → 22: 17.87°
#     Embedding 22 → 23: 18.44°
#   Frase 40:
#     Embedding 0 → 1: 90.98°
#     Embedding 1 → 2: 86.95°
#     Embedding 2 → 3: 82.10°
#     Embedding 3 → 4: 83.60°
#     Embedding 4 → 5: 87.52°
#     Embedding 5 → 6: 80.24°
#     Embedding 6 → 7: 86.16°
#     Embedding 7 → 8: 84.99°
#     Embedding 8 → 9: 82.28°
#     Embedding 9 → 10: 80.43°
#     Embedding 10 → 11: 81.96°
#     Embedding 11 → 12: 84.11°
#     Embedding 12 → 13: 88.62°
#     Embedding 13 → 14: 81.99°
#     Embedding 14 → 15: 85.39°
#     Embedding 15 → 16: 68.95°
#     Embedding 16 → 17: 81.88°
#     Embedding 17 → 18: 18.96°
#     Embedding 18 → 19: 18.83°
#     Embedding 19 → 20: 18.41°
#     Embedding 20 → 21: 18.65°
#     Embedding 21 → 22: 17.87°
#     Embedding 22 → 23: 18.44°
#   Frase 41:
#     Embedding 0 → 1: 90.64°
#     Embedding 1 → 2: 86.56°
#     Embedding 2 → 3: 82.94°
#     Embedding 3 → 4: 81.57°
#     Embedding 4 → 5: 83.81°
#     Embedding 5 → 6: 85.74°
#     Embedding 6 → 7: 80.83°
#     Embedding 7 → 8: 81.13°
#     Embedding 8 → 9: 87.55°
#     Embedding 9 → 10: 87.88°
#     Embedding 10 → 11: 86.04°
#     Embedding 11 → 12: 86.21°
#     Embedding 12 → 13: 83.53°
#     Embedding 13 → 14: 80.93°
#     Embedding 14 → 15: 69.01°
#     Embedding 15 → 16: 81.02°
#     Embedding 16 → 17: 19.23°
#     Embedding 17 → 18: 18.96°
#     Embedding 18 → 19: 18.83°
#     Embedding 19 → 20: 18.41°
#     Embedding 20 → 21: 18.65°
#     Embedding 21 → 22: 17.87°
#     Embedding 22 → 23: 18.44°
#   Frase 42:
#     Embedding 0 → 1: 88.53°
#     Embedding 1 → 2: 85.63°
#     Embedding 2 → 3: 76.27°
#     Embedding 3 → 4: 81.23°
#     Embedding 4 → 5: 84.31°
#     Embedding 5 → 6: 85.30°
#     Embedding 6 → 7: 81.79°
#     Embedding 7 → 8: 87.09°
#     Embedding 8 → 9: 82.99°
#     Embedding 9 → 10: 87.90°
#     Embedding 10 → 11: 84.08°
#     Embedding 11 → 12: 88.03°
#     Embedding 12 → 13: 86.79°
#     Embedding 13 → 14: 84.70°
#     Embedding 14 → 15: 84.90°
#     Embedding 15 → 16: 68.95°
#     Embedding 16 → 17: 81.88°
#     Embedding 17 → 18: 18.96°
#     Embedding 18 → 19: 18.83°
#     Embedding 19 → 20: 18.41°
#     Embedding 20 → 21: 18.65°
#     Embedding 21 → 22: 17.87°
#     Embedding 22 → 23: 18.44°
#   Frase 43:
#     Embedding 0 → 1: 89.94°
#     Embedding 1 → 2: 81.85°
#     Embedding 2 → 3: 83.45°
#     Embedding 3 → 4: 87.13°
#     Embedding 4 → 5: 88.77°
#     Embedding 5 → 6: 86.44°
#     Embedding 6 → 7: 79.72°
#     Embedding 7 → 8: 81.79°
#     Embedding 8 → 9: 86.94°
#     Embedding 9 → 10: 88.39°
#     Embedding 10 → 11: 86.74°
#     Embedding 11 → 12: 83.63°
#     Embedding 12 → 13: 84.55°
#     Embedding 13 → 14: 83.58°
#     Embedding 14 → 15: 84.86°
#     Embedding 15 → 16: 84.52°
#     Embedding 16 → 17: 85.37°
#     Embedding 17 → 18: 83.47°
#     Embedding 18 → 19: 83.50°
#     Embedding 19 → 20: 78.91°
#     Embedding 20 → 21: 84.56°
#     Embedding 21 → 22: 84.45°
#     Embedding 22 → 23: 68.85°
#   Frase 44:
#     Embedding 0 → 1: 89.75°
#     Embedding 1 → 2: 84.91°
#     Embedding 2 → 3: 84.16°
#     Embedding 3 → 4: 86.92°
#     Embedding 4 → 5: 82.80°
#     Embedding 5 → 6: 84.43°
#     Embedding 6 → 7: 84.25°
#     Embedding 7 → 8: 75.63°
#     Embedding 8 → 9: 80.87°
#     Embedding 9 → 10: 82.26°
#     Embedding 10 → 11: 83.56°
#     Embedding 11 → 12: 83.96°
#     Embedding 12 → 13: 83.10°
#     Embedding 13 → 14: 86.21°
#     Embedding 14 → 15: 69.01°
#     Embedding 15 → 16: 81.02°
#     Embedding 16 → 17: 19.23°
#     Embedding 17 → 18: 18.96°
#     Embedding 18 → 19: 18.83°
#     Embedding 19 → 20: 18.41°
#     Embedding 20 → 21: 18.65°
#     Embedding 21 → 22: 17.87°
#     Embedding 22 → 23: 18.44°
#   Frase 45:
#     Embedding 0 → 1: 89.55°
#     Embedding 1 → 2: 82.99°
#     Embedding 2 → 3: 84.45°
#     Embedding 3 → 4: 80.79°
#     Embedding 4 → 5: 84.89°
#     Embedding 5 → 6: 80.38°
#     Embedding 6 → 7: 83.47°
#     Embedding 7 → 8: 88.30°
#     Embedding 8 → 9: 84.92°
#     Embedding 9 → 10: 84.42°
#     Embedding 10 → 11: 70.25°
#     Embedding 11 → 12: 81.99°
#     Embedding 12 → 13: 18.48°
#     Embedding 13 → 14: 18.98°
#     Embedding 14 → 15: 18.64°
#     Embedding 15 → 16: 19.24°
#     Embedding 16 → 17: 19.23°
#     Embedding 17 → 18: 18.96°
#     Embedding 18 → 19: 18.83°
#     Embedding 19 → 20: 18.41°
#     Embedding 20 → 21: 18.65°
#     Embedding 21 → 22: 17.87°
#     Embedding 22 → 23: 18.44°
#   Frase 46:
#     Embedding 0 → 1: 89.50°
#     Embedding 1 → 2: 85.65°
#     Embedding 2 → 3: 81.34°
#     Embedding 3 → 4: 84.22°
#     Embedding 4 → 5: 82.17°
#     Embedding 5 → 6: 82.36°
#     Embedding 6 → 7: 83.93°
#     Embedding 7 → 8: 78.88°
#     Embedding 8 → 9: 86.33°
#     Embedding 9 → 10: 85.46°
#     Embedding 10 → 11: 84.21°
#     Embedding 11 → 12: 81.85°
#     Embedding 12 → 13: 80.91°
#     Embedding 13 → 14: 83.67°
#     Embedding 14 → 15: 86.36°
#     Embedding 15 → 16: 84.55°
#     Embedding 16 → 17: 84.44°
#     Embedding 17 → 18: 69.73°
#     Embedding 18 → 19: 80.73°
#     Embedding 19 → 20: 18.41°
#     Embedding 20 → 21: 18.65°
#     Embedding 21 → 22: 17.87°
#     Embedding 22 → 23: 18.44°
#   Frase 47:
#     Embedding 0 → 1: 90.59°
#     Embedding 1 → 2: 85.35°
#     Embedding 2 → 3: 81.92°
#     Embedding 3 → 4: 87.20°
#     Embedding 4 → 5: 86.80°
#     Embedding 5 → 6: 84.20°
#     Embedding 6 → 7: 87.32°
#     Embedding 7 → 8: 81.34°
#     Embedding 8 → 9: 84.68°
#     Embedding 9 → 10: 86.35°
#     Embedding 10 → 11: 78.72°
#     Embedding 11 → 12: 85.91°
#     Embedding 12 → 13: 86.98°
#     Embedding 13 → 14: 83.13°
#     Embedding 14 → 15: 87.61°
#     Embedding 15 → 16: 84.82°
#     Embedding 16 → 17: 69.43°
#     Embedding 17 → 18: 82.34°
#     Embedding 18 → 19: 18.83°
#     Embedding 19 → 20: 18.41°
#     Embedding 20 → 21: 18.65°
#     Embedding 21 → 22: 17.87°
#     Embedding 22 → 23: 18.44°
#   Frase 48:
#     Embedding 0 → 1: 88.24°
#     Embedding 1 → 2: 86.53°
#     Embedding 2 → 3: 91.08°
#     Embedding 3 → 4: 89.97°
#     Embedding 4 → 5: 85.56°
#     Embedding 5 → 6: 87.08°
#     Embedding 6 → 7: 83.61°
#     Embedding 7 → 8: 84.25°
#     Embedding 8 → 9: 87.26°
#     Embedding 9 → 10: 69.65°
#     Embedding 10 → 11: 82.19°
#     Embedding 11 → 12: 18.07°
#     Embedding 12 → 13: 18.48°
#     Embedding 13 → 14: 18.98°
#     Embedding 14 → 15: 18.64°
#     Embedding 15 → 16: 19.24°
#     Embedding 16 → 17: 19.23°
#     Embedding 17 → 18: 18.96°
#     Embedding 18 → 19: 18.83°
#     Embedding 19 → 20: 18.41°
#     Embedding 20 → 21: 18.65°
#     Embedding 21 → 22: 17.87°
#     Embedding 22 → 23: 18.44°
#   Frase 49:
#     Embedding 0 → 1: 90.49°
#     Embedding 1 → 2: 82.86°
#     Embedding 2 → 3: 77.34°
#     Embedding 3 → 4: 87.61°
#     Embedding 4 → 5: 85.72°
#     Embedding 5 → 6: 83.76°
#     Embedding 6 → 7: 87.77°
#     Embedding 7 → 8: 86.74°
#     Embedding 8 → 9: 74.83°
#     Embedding 9 → 10: 88.30°
#     Embedding 10 → 11: 87.51°
#     Embedding 11 → 12: 84.92°
#     Embedding 12 → 13: 86.64°
#     Embedding 13 → 14: 85.01°
#     Embedding 14 → 15: 74.42°
#     Embedding 15 → 16: 68.95°
#     Embedding 16 → 17: 81.88°
#     Embedding 17 → 18: 18.96°
#     Embedding 18 → 19: 18.83°
#     Embedding 19 → 20: 18.41°
#     Embedding 20 → 21: 18.65°
#     Embedding 21 → 22: 17.87°
#     Embedding 22 → 23: 18.44°
#   Frase 50:
#     Embedding 0 → 1: 90.64°
#     Embedding 1 → 2: 86.71°
#     Embedding 2 → 3: 85.99°
#     Embedding 3 → 4: 82.59°
#     Embedding 4 → 5: 85.45°
#     Embedding 5 → 6: 83.48°
#     Embedding 6 → 7: 83.84°
#     Embedding 7 → 8: 83.72°
#     Embedding 8 → 9: 85.90°
#     Embedding 9 → 10: 80.40°
#     Embedding 10 → 11: 83.55°
#     Embedding 11 → 12: 85.86°
#     Embedding 12 → 13: 83.74°
#     Embedding 13 → 14: 80.42°
#     Embedding 14 → 15: 69.01°
#     Embedding 15 → 16: 81.02°
#     Embedding 16 → 17: 19.23°
#     Embedding 17 → 18: 18.96°
#     Embedding 18 → 19: 18.83°
#     Embedding 19 → 20: 18.41°
#     Embedding 20 → 21: 18.65°
#     Embedding 21 → 22: 17.87°
#     Embedding 22 → 23: 18.44°
#   Frase 51:
#     Embedding 0 → 1: 88.53°
#     Embedding 1 → 2: 85.63°
#     Embedding 2 → 3: 76.27°
#     Embedding 3 → 4: 81.23°
#     Embedding 4 → 5: 84.31°
#     Embedding 5 → 6: 85.30°
#     Embedding 6 → 7: 81.79°
#     Embedding 7 → 8: 87.09°
#     Embedding 8 → 9: 82.99°
#     Embedding 9 → 10: 87.90°
#     Embedding 10 → 11: 84.08°
#     Embedding 11 → 12: 88.03°
#     Embedding 12 → 13: 86.79°
#     Embedding 13 → 14: 84.70°
#     Embedding 14 → 15: 84.90°
#     Embedding 15 → 16: 68.95°
#     Embedding 16 → 17: 81.88°
#     Embedding 17 → 18: 18.96°
#     Embedding 18 → 19: 18.83°
#     Embedding 19 → 20: 18.41°
#     Embedding 20 → 21: 18.65°
#     Embedding 21 → 22: 17.87°
#     Embedding 22 → 23: 18.44°
#   Frase 52:
#     Embedding 0 → 1: 91.49°
#     Embedding 1 → 2: 81.10°
#     Embedding 2 → 3: 84.45°
#     Embedding 3 → 4: 84.82°
#     Embedding 4 → 5: 75.57°
#     Embedding 5 → 6: 81.34°
#     Embedding 6 → 7: 83.41°
#     Embedding 7 → 8: 90.91°
#     Embedding 8 → 9: 84.56°
#     Embedding 9 → 10: 85.93°
#     Embedding 10 → 11: 82.23°
#     Embedding 11 → 12: 85.22°
#     Embedding 12 → 13: 80.82°
#     Embedding 13 → 14: 86.59°
#     Embedding 14 → 15: 86.48°
#     Embedding 15 → 16: 88.54°
#     Embedding 16 → 17: 87.57°
#     Embedding 17 → 18: 69.73°
#     Embedding 18 → 19: 80.73°
#     Embedding 19 → 20: 18.41°
#     Embedding 20 → 21: 18.65°
#     Embedding 21 → 22: 17.87°
#     Embedding 22 → 23: 18.44°
#   Frase 53:
#     Embedding 0 → 1: 91.24°
#     Embedding 1 → 2: 86.90°
#     Embedding 2 → 3: 82.82°
#     Embedding 3 → 4: 84.92°
#     Embedding 4 → 5: 79.99°
#     Embedding 5 → 6: 86.98°
#     Embedding 6 → 7: 90.68°
#     Embedding 7 → 8: 87.01°
#     Embedding 8 → 9: 85.80°
#     Embedding 9 → 10: 85.05°
#     Embedding 10 → 11: 87.35°
#     Embedding 11 → 12: 82.05°
#     Embedding 12 → 13: 85.80°
#     Embedding 13 → 14: 69.74°
#     Embedding 14 → 15: 81.73°
#     Embedding 15 → 16: 19.24°
#     Embedding 16 → 17: 19.23°
#     Embedding 17 → 18: 18.96°
#     Embedding 18 → 19: 18.83°
#     Embedding 19 → 20: 18.41°
#     Embedding 20 → 21: 18.65°
#     Embedding 21 → 22: 17.87°
#     Embedding 22 → 23: 18.44°
#   Frase 54:
#     Embedding 0 → 1: 89.55°
#     Embedding 1 → 2: 82.99°
#     Embedding 2 → 3: 84.45°
#     Embedding 3 → 4: 80.79°
#     Embedding 4 → 5: 84.89°
#     Embedding 5 → 6: 80.38°
#     Embedding 6 → 7: 83.47°
#     Embedding 7 → 8: 88.30°
#     Embedding 8 → 9: 84.92°
#     Embedding 9 → 10: 84.42°
#     Embedding 10 → 11: 70.25°
#     Embedding 11 → 12: 81.99°
#     Embedding 12 → 13: 18.48°
#     Embedding 13 → 14: 18.98°
#     Embedding 14 → 15: 18.64°
#     Embedding 15 → 16: 19.24°
#     Embedding 16 → 17: 19.23°
#     Embedding 17 → 18: 18.96°
#     Embedding 18 → 19: 18.83°
#     Embedding 19 → 20: 18.41°
#     Embedding 20 → 21: 18.65°
#     Embedding 21 → 22: 17.87°
#     Embedding 22 → 23: 18.44°
#   Frase 55:
#     Embedding 0 → 1: 89.32°
#     Embedding 1 → 2: 86.55°
#     Embedding 2 → 3: 84.64°
#     Embedding 3 → 4: 79.77°
#     Embedding 4 → 5: 85.61°
#     Embedding 5 → 6: 83.72°
#     Embedding 6 → 7: 76.59°
#     Embedding 7 → 8: 84.75°
#     Embedding 8 → 9: 86.22°
#     Embedding 9 → 10: 81.90°
#     Embedding 10 → 11: 82.88°
#     Embedding 11 → 12: 83.67°
#     Embedding 12 → 13: 77.05°
#     Embedding 13 → 14: 81.72°
#     Embedding 14 → 15: 18.64°
#     Embedding 15 → 16: 19.24°
#     Embedding 16 → 17: 19.23°
#     Embedding 17 → 18: 18.96°
#     Embedding 18 → 19: 18.83°
#     Embedding 19 → 20: 18.41°
#     Embedding 20 → 21: 18.65°
#     Embedding 21 → 22: 17.87°
#     Embedding 22 → 23: 18.44°
#   Frase 56:
#     Embedding 0 → 1: 90.49°
#     Embedding 1 → 2: 82.86°
#     Embedding 2 → 3: 77.34°
#     Embedding 3 → 4: 87.61°
#     Embedding 4 → 5: 85.72°
#     Embedding 5 → 6: 83.76°
#     Embedding 6 → 7: 87.77°
#     Embedding 7 → 8: 86.74°
#     Embedding 8 → 9: 74.83°
#     Embedding 9 → 10: 88.30°
#     Embedding 10 → 11: 87.51°
#     Embedding 11 → 12: 84.92°
#     Embedding 12 → 13: 86.64°
#     Embedding 13 → 14: 85.01°
#     Embedding 14 → 15: 74.42°
#     Embedding 15 → 16: 68.95°
#     Embedding 16 → 17: 81.88°
#     Embedding 17 → 18: 18.96°
#     Embedding 18 → 19: 18.83°
#     Embedding 19 → 20: 18.41°
#     Embedding 20 → 21: 18.65°
#     Embedding 21 → 22: 17.87°
#     Embedding 22 → 23: 18.44°
#
# Camada 1:
#   Frase 0:
#     Embedding 0 → 1: 83.28°
#     Embedding 1 → 2: 77.76°
#     Embedding 2 → 3: 74.87°
#     Embedding 3 → 4: 75.84°
#     Embedding 4 → 5: 76.59°
#     Embedding 5 → 6: 68.82°
#     Embedding 6 → 7: 76.67°
#     Embedding 7 → 8: 74.12°
#     Embedding 8 → 9: 70.40°
#     Embedding 9 → 10: 68.01°
#     Embedding 10 → 11: 69.74°
#     Embedding 11 → 12: 77.35°
#     Embedding 12 → 13: 79.31°
#     Embedding 13 → 14: 72.89°
#     Embedding 14 → 15: 72.48°
#     Embedding 15 → 16: 51.37°
#     Embedding 16 → 17: 53.89°
#     Embedding 17 → 18: 15.50°
#     Embedding 18 → 19: 13.33°
#     Embedding 19 → 20: 12.49°
#     Embedding 20 → 21: 12.81°
#     Embedding 21 → 22: 12.28°
#     Embedding 22 → 23: 11.48°
#   Frase 1:
#     Embedding 0 → 1: 83.45°
#     Embedding 1 → 2: 70.73°
#     Embedding 2 → 3: 76.47°
#     Embedding 3 → 4: 76.98°
#     Embedding 4 → 5: 72.89°
#     Embedding 5 → 6: 73.99°
#     Embedding 6 → 7: 70.01°
#     Embedding 7 → 8: 73.49°
#     Embedding 8 → 9: 77.58°
#     Embedding 9 → 10: 75.06°
#     Embedding 10 → 11: 72.10°
#     Embedding 11 → 12: 69.08°
#     Embedding 12 → 13: 74.02°
#     Embedding 13 → 14: 68.07°
#     Embedding 14 → 15: 73.65°
#     Embedding 15 → 16: 72.94°
#     Embedding 16 → 17: 74.27°
#     Embedding 17 → 18: 67.71°
#     Embedding 18 → 19: 73.22°
#     Embedding 19 → 20: 67.63°
#     Embedding 20 → 21: 50.77°
#     Embedding 21 → 22: 52.88°
#     Embedding 22 → 23: 12.98°
#   Frase 2:
#     Embedding 0 → 1: 83.28°
#     Embedding 1 → 2: 77.76°
#     Embedding 2 → 3: 74.87°
#     Embedding 3 → 4: 75.84°
#     Embedding 4 → 5: 76.59°
#     Embedding 5 → 6: 68.82°
#     Embedding 6 → 7: 76.67°
#     Embedding 7 → 8: 74.12°
#     Embedding 8 → 9: 70.40°
#     Embedding 9 → 10: 68.01°
#     Embedding 10 → 11: 69.74°
#     Embedding 11 → 12: 77.35°
#     Embedding 12 → 13: 79.31°
#     Embedding 13 → 14: 72.89°
#     Embedding 14 → 15: 72.48°
#     Embedding 15 → 16: 51.37°
#     Embedding 16 → 17: 53.89°
#     Embedding 17 → 18: 15.50°
#     Embedding 18 → 19: 13.33°
#     Embedding 19 → 20: 12.49°
#     Embedding 20 → 21: 12.81°
#     Embedding 21 → 22: 12.28°
#     Embedding 22 → 23: 11.48°
#   Frase 3:
#     Embedding 0 → 1: 83.23°
#     Embedding 1 → 2: 76.41°
#     Embedding 2 → 3: 77.17°
#     Embedding 3 → 4: 69.03°
#     Embedding 4 → 5: 72.97°
#     Embedding 5 → 6: 75.02°
#     Embedding 6 → 7: 75.30°
#     Embedding 7 → 8: 72.73°
#     Embedding 8 → 9: 74.00°
#     Embedding 9 → 10: 75.46°
#     Embedding 10 → 11: 78.89°
#     Embedding 11 → 12: 78.08°
#     Embedding 12 → 13: 74.71°
#     Embedding 13 → 14: 74.44°
#     Embedding 14 → 15: 74.26°
#     Embedding 15 → 16: 75.04°
#     Embedding 16 → 17: 73.58°
#     Embedding 17 → 18: 52.11°
#     Embedding 18 → 19: 53.86°
#     Embedding 19 → 20: 13.24°
#     Embedding 20 → 21: 12.91°
#     Embedding 21 → 22: 12.01°
#     Embedding 22 → 23: 12.18°
#   Frase 4:
#     Embedding 0 → 1: 85.35°
#     Embedding 1 → 2: 73.63°
#     Embedding 2 → 3: 73.44°
#     Embedding 3 → 4: 76.47°
#     Embedding 4 → 5: 78.81°
#     Embedding 5 → 6: 74.74°
#     Embedding 6 → 7: 62.46°
#     Embedding 7 → 8: 72.89°
#     Embedding 8 → 9: 79.38°
#     Embedding 9 → 10: 78.43°
#     Embedding 10 → 11: 73.40°
#     Embedding 11 → 12: 75.27°
#     Embedding 12 → 13: 67.72°
#     Embedding 13 → 14: 72.88°
#     Embedding 14 → 15: 51.15°
#     Embedding 15 → 16: 54.09°
#     Embedding 16 → 17: 13.66°
#     Embedding 17 → 18: 12.16°
#     Embedding 18 → 19: 12.36°
#     Embedding 19 → 20: 11.62°
#     Embedding 20 → 21: 12.19°
#     Embedding 21 → 22: 11.67°
#     Embedding 22 → 23: 11.48°
#   Frase 5:
#     Embedding 0 → 1: 83.05°
#     Embedding 1 → 2: 75.79°
#     Embedding 2 → 3: 77.23°
#     Embedding 3 → 4: 69.62°
#     Embedding 4 → 5: 74.69°
#     Embedding 5 → 6: 75.44°
#     Embedding 6 → 7: 77.89°
#     Embedding 7 → 8: 70.14°
#     Embedding 8 → 9: 68.12°
#     Embedding 9 → 10: 67.96°
#     Embedding 10 → 11: 73.97°
#     Embedding 11 → 12: 73.04°
#     Embedding 12 → 13: 71.13°
#     Embedding 13 → 14: 74.24°
#     Embedding 14 → 15: 74.44°
#     Embedding 15 → 16: 74.77°
#     Embedding 16 → 17: 72.75°
#     Embedding 17 → 18: 79.85°
#     Embedding 18 → 19: 74.65°
#     Embedding 19 → 20: 50.72°
#     Embedding 20 → 21: 54.30°
#     Embedding 21 → 22: 12.62°
#     Embedding 22 → 23: 11.48°
#   Frase 6:
#     Embedding 0 → 1: 82.83°
#     Embedding 1 → 2: 76.36°
#     Embedding 2 → 3: 77.64°
#     Embedding 3 → 4: 71.38°
#     Embedding 4 → 5: 56.68°
#     Embedding 5 → 6: 75.87°
#     Embedding 6 → 7: 74.85°
#     Embedding 7 → 8: 69.46°
#     Embedding 8 → 9: 73.68°
#     Embedding 9 → 10: 69.26°
#     Embedding 10 → 11: 51.52°
#     Embedding 11 → 12: 54.63°
#     Embedding 12 → 13: 14.21°
#     Embedding 13 → 14: 13.31°
#     Embedding 14 → 15: 13.30°
#     Embedding 15 → 16: 14.07°
#     Embedding 16 → 17: 13.82°
#     Embedding 17 → 18: 13.73°
#     Embedding 18 → 19: 13.57°
#     Embedding 19 → 20: 13.37°
#     Embedding 20 → 21: 13.54°
#     Embedding 21 → 22: 13.76°
#     Embedding 22 → 23: 11.80°
#   Frase 7:
#     Embedding 0 → 1: 84.62°
#     Embedding 1 → 2: 78.78°
#     Embedding 2 → 3: 77.94°
#     Embedding 3 → 4: 75.79°
#     Embedding 4 → 5: 76.52°
#     Embedding 5 → 6: 75.66°
#     Embedding 6 → 7: 79.44°
#     Embedding 7 → 8: 75.03°
#     Embedding 8 → 9: 63.48°
#     Embedding 9 → 10: 72.48°
#     Embedding 10 → 11: 77.03°
#     Embedding 11 → 12: 76.56°
#     Embedding 12 → 13: 75.23°
#     Embedding 13 → 14: 12.61°
#     Embedding 14 → 15: 70.32°
#     Embedding 15 → 16: 73.39°
#     Embedding 16 → 17: 52.07°
#     Embedding 17 → 18: 54.86°
#     Embedding 18 → 19: 13.83°
#     Embedding 19 → 20: 12.06°
#     Embedding 20 → 21: 12.30°
#     Embedding 21 → 22: 12.28°
#     Embedding 22 → 23: 11.37°
#   Frase 8:
#     Embedding 0 → 1: 82.83°
#     Embedding 1 → 2: 76.36°
#     Embedding 2 → 3: 77.64°
#     Embedding 3 → 4: 71.38°
#     Embedding 4 → 5: 56.68°
#     Embedding 5 → 6: 75.87°
#     Embedding 6 → 7: 74.85°
#     Embedding 7 → 8: 69.46°
#     Embedding 8 → 9: 73.68°
#     Embedding 9 → 10: 69.26°
#     Embedding 10 → 11: 51.52°
#     Embedding 11 → 12: 54.63°
#     Embedding 12 → 13: 14.21°
#     Embedding 13 → 14: 13.31°
#     Embedding 14 → 15: 13.30°
#     Embedding 15 → 16: 14.07°
#     Embedding 16 → 17: 13.82°
#     Embedding 17 → 18: 13.73°
#     Embedding 18 → 19: 13.57°
#     Embedding 19 → 20: 13.37°
#     Embedding 20 → 21: 13.54°
#     Embedding 21 → 22: 13.76°
#     Embedding 22 → 23: 11.80°
#   Frase 9:
#     Embedding 0 → 1: 83.83°
#     Embedding 1 → 2: 71.56°
#     Embedding 2 → 3: 74.60°
#     Embedding 3 → 4: 75.90°
#     Embedding 4 → 5: 66.45°
#     Embedding 5 → 6: 71.75°
#     Embedding 6 → 7: 75.94°
#     Embedding 7 → 8: 80.94°
#     Embedding 8 → 9: 76.24°
#     Embedding 9 → 10: 74.41°
#     Embedding 10 → 11: 71.41°
#     Embedding 11 → 12: 72.96°
#     Embedding 12 → 13: 71.56°
#     Embedding 13 → 14: 74.97°
#     Embedding 14 → 15: 73.66°
#     Embedding 15 → 16: 75.36°
#     Embedding 16 → 17: 74.68°
#     Embedding 17 → 18: 51.18°
#     Embedding 18 → 19: 52.62°
#     Embedding 19 → 20: 13.89°
#     Embedding 20 → 21: 12.76°
#     Embedding 21 → 22: 12.17°
#     Embedding 22 → 23: 12.02°
#   Frase 10:
#     Embedding 0 → 1: 83.45°
#     Embedding 1 → 2: 70.73°
#     Embedding 2 → 3: 76.47°
#     Embedding 3 → 4: 76.98°
#     Embedding 4 → 5: 72.89°
#     Embedding 5 → 6: 73.99°
#     Embedding 6 → 7: 70.01°
#     Embedding 7 → 8: 73.49°
#     Embedding 8 → 9: 77.58°
#     Embedding 9 → 10: 75.06°
#     Embedding 10 → 11: 72.10°
#     Embedding 11 → 12: 69.08°
#     Embedding 12 → 13: 74.02°
#     Embedding 13 → 14: 68.07°
#     Embedding 14 → 15: 73.65°
#     Embedding 15 → 16: 72.94°
#     Embedding 16 → 17: 74.27°
#     Embedding 17 → 18: 67.71°
#     Embedding 18 → 19: 73.22°
#     Embedding 19 → 20: 67.63°
#     Embedding 20 → 21: 50.77°
#     Embedding 21 → 22: 52.88°
#     Embedding 22 → 23: 12.98°
#   Frase 11:
#     Embedding 0 → 1: 83.05°
#     Embedding 1 → 2: 75.79°
#     Embedding 2 → 3: 77.23°
#     Embedding 3 → 4: 69.62°
#     Embedding 4 → 5: 74.69°
#     Embedding 5 → 6: 75.44°
#     Embedding 6 → 7: 77.89°
#     Embedding 7 → 8: 70.14°
#     Embedding 8 → 9: 68.12°
#     Embedding 9 → 10: 67.96°
#     Embedding 10 → 11: 73.97°
#     Embedding 11 → 12: 73.04°
#     Embedding 12 → 13: 71.13°
#     Embedding 13 → 14: 74.24°
#     Embedding 14 → 15: 74.44°
#     Embedding 15 → 16: 74.77°
#     Embedding 16 → 17: 72.75°
#     Embedding 17 → 18: 79.85°
#     Embedding 18 → 19: 74.65°
#     Embedding 19 → 20: 50.72°
#     Embedding 20 → 21: 54.30°
#     Embedding 21 → 22: 12.62°
#     Embedding 22 → 23: 11.48°
#   Frase 12:
#     Embedding 0 → 1: 82.60°
#     Embedding 1 → 2: 74.45°
#     Embedding 2 → 3: 77.01°
#     Embedding 3 → 4: 73.14°
#     Embedding 4 → 5: 74.10°
#     Embedding 5 → 6: 68.50°
#     Embedding 6 → 7: 72.73°
#     Embedding 7 → 8: 76.69°
#     Embedding 8 → 9: 74.92°
#     Embedding 9 → 10: 76.18°
#     Embedding 10 → 11: 71.40°
#     Embedding 11 → 12: 72.67°
#     Embedding 12 → 13: 50.62°
#     Embedding 13 → 14: 52.25°
#     Embedding 14 → 15: 14.98°
#     Embedding 15 → 16: 13.69°
#     Embedding 16 → 17: 13.20°
#     Embedding 17 → 18: 13.60°
#     Embedding 18 → 19: 13.41°
#     Embedding 19 → 20: 12.67°
#     Embedding 20 → 21: 13.15°
#     Embedding 21 → 22: 13.09°
#     Embedding 22 → 23: 11.93°
#   Frase 13:
#     Embedding 0 → 1: 82.15°
#     Embedding 1 → 2: 75.59°
#     Embedding 2 → 3: 75.53°
#     Embedding 3 → 4: 73.42°
#     Embedding 4 → 5: 69.14°
#     Embedding 5 → 6: 78.50°
# ...
#     Embedding 13 → 14: 53.27°
#     Embedding 14 → 15: 48.25°
#     Embedding 15 → 16: 34.43°
#     Embedding 16 → 17: 35.30°
#     Embedding 17 → 18: 20.07°
#     Embedding 18 → 19: 27.27°
#     Embedding 19 → 20: 31.38°
#     Embedding 20 → 21: 30.89°
#     Embedding 21 → 22: 2.48°
#     Embedding 22 → 23: 56.91°
#   Frase 34:
#     Embedding 0 → 1: 73.42°
#     Embedding 1 → 2: 70.54°
#     Embedding 2 → 3: 65.34°
#     Embedding 3 → 4: 53.88°
#     Embedding 4 → 5: 61.79°
#     Embedding 5 → 6: 63.81°
#     Embedding 6 → 7: 60.81°
#     Embedding 7 → 8: 56.17°
#     Embedding 8 → 9: 61.37°
#     Embedding 9 → 10: 51.58°
#     Embedding 10 → 11: 61.51°
#     Embedding 11 → 12: 60.67°
#     Embedding 12 → 13: 17.82°
#     Embedding 13 → 14: 53.27°
#     Embedding 14 → 15: 48.25°
#     Embedding 15 → 16: 34.43°
#     Embedding 16 → 17: 35.30°
#     Embedding 17 → 18: 20.07°
#     Embedding 18 → 19: 27.27°
#     Embedding 19 → 20: 31.38°
#     Embedding 20 → 21: 30.89°
#     Embedding 21 → 22: 2.48°
#     Embedding 22 → 23: 56.91°
#   Frase 35:
#     Embedding 0 → 1: 76.76°
#     Embedding 1 → 2: 67.79°
#     Embedding 2 → 3: 66.84°
#     Embedding 3 → 4: 72.42°
#     Embedding 4 → 5: 71.32°
#     Embedding 5 → 6: 71.11°
#     Embedding 6 → 7: 52.75°
#     Embedding 7 → 8: 57.53°
#     Embedding 8 → 9: 64.23°
#     Embedding 9 → 10: 70.32°
#     Embedding 10 → 11: 65.90°
#     Embedding 11 → 12: 56.76°
#     Embedding 12 → 13: 55.09°
#     Embedding 13 → 14: 60.91°
#     Embedding 14 → 15: 60.10°
#     Embedding 15 → 16: 60.12°
#     Embedding 16 → 17: 64.85°
#     Embedding 17 → 18: 67.93°
#     Embedding 18 → 19: 69.55°
#     Embedding 19 → 20: 54.54°
#     Embedding 20 → 21: 63.08°
#     Embedding 21 → 22: 54.39°
#     Embedding 22 → 23: 65.53°
#   Frase 36:
#     Embedding 0 → 1: 77.00°
#     Embedding 1 → 2: 56.85°
#     Embedding 2 → 3: 64.57°
#     Embedding 3 → 4: 61.08°
#     Embedding 4 → 5: 59.71°
#     Embedding 5 → 6: 56.46°
#     Embedding 6 → 7: 66.43°
#     Embedding 7 → 8: 58.77°
#     Embedding 8 → 9: 64.42°
#     Embedding 9 → 10: 52.68°
#     Embedding 10 → 11: 62.86°
#     Embedding 11 → 12: 56.05°
#     Embedding 12 → 13: 60.65°
#     Embedding 13 → 14: 62.13°
#     Embedding 14 → 15: 28.70°
#     Embedding 15 → 16: 35.23°
#     Embedding 16 → 17: 32.81°
#     Embedding 17 → 18: 33.98°
#     Embedding 18 → 19: 57.21°
#     Embedding 19 → 20: 58.40°
#     Embedding 20 → 21: 34.40°
#     Embedding 21 → 22: 62.55°
#     Embedding 22 → 23: 55.25°
#   Frase 37:
#     Embedding 0 → 1: 75.58°
#     Embedding 1 → 2: 70.25°
#     Embedding 2 → 3: 70.29°
#     Embedding 3 → 4: 52.12°
#     Embedding 4 → 5: 41.64°
#     Embedding 5 → 6: 45.57°
#     Embedding 6 → 7: 61.36°
#     Embedding 7 → 8: 52.73°
#     Embedding 8 → 9: 58.96°
#     Embedding 9 → 10: 71.32°
#     Embedding 10 → 11: 58.90°
#     Embedding 11 → 12: 58.01°
#     Embedding 12 → 13: 71.05°
#     Embedding 13 → 14: 62.35°
#     Embedding 14 → 15: 69.34°
#     Embedding 15 → 16: 56.67°
#     Embedding 16 → 17: 67.43°
#     Embedding 17 → 18: 64.50°
#     Embedding 18 → 19: 6.89°
#     Embedding 19 → 20: 18.82°
#     Embedding 20 → 21: 17.90°
#     Embedding 21 → 22: 43.61°
#     Embedding 22 → 23: 19.78°
#   Frase 38:
#     Embedding 0 → 1: 74.12°
#     Embedding 1 → 2: 63.65°
#     Embedding 2 → 3: 69.11°
#     Embedding 3 → 4: 68.04°
#     Embedding 4 → 5: 61.08°
#     Embedding 5 → 6: 64.12°
#     Embedding 6 → 7: 72.50°
#     Embedding 7 → 8: 68.22°
#     Embedding 8 → 9: 66.67°
#     Embedding 9 → 10: 57.59°
#     Embedding 10 → 11: 58.89°
#     Embedding 11 → 12: 49.81°
#     Embedding 12 → 13: 63.37°
#     Embedding 13 → 14: 69.64°
#     Embedding 14 → 15: 54.28°
#     Embedding 15 → 16: 27.59°
#     Embedding 16 → 17: 25.73°
#     Embedding 17 → 18: 58.08°
#     Embedding 18 → 19: 19.54°
#     Embedding 19 → 20: 47.66°
#     Embedding 20 → 21: 47.02°
#     Embedding 21 → 22: 3.75°
#     Embedding 22 → 23: 55.24°
#   Frase 39:
#     Embedding 0 → 1: 74.12°
#     Embedding 1 → 2: 63.65°
#     Embedding 2 → 3: 69.11°
#     Embedding 3 → 4: 68.04°
#     Embedding 4 → 5: 61.08°
#     Embedding 5 → 6: 64.12°
#     Embedding 6 → 7: 72.50°
#     Embedding 7 → 8: 68.22°
#     Embedding 8 → 9: 66.67°
#     Embedding 9 → 10: 57.59°
#     Embedding 10 → 11: 58.89°
#     Embedding 11 → 12: 49.81°
#     Embedding 12 → 13: 63.37°
#     Embedding 13 → 14: 69.64°
#     Embedding 14 → 15: 54.28°
#     Embedding 15 → 16: 27.59°
#     Embedding 16 → 17: 25.73°
#     Embedding 17 → 18: 58.08°
#     Embedding 18 → 19: 19.54°
#     Embedding 19 → 20: 47.66°
#     Embedding 20 → 21: 47.02°
#     Embedding 21 → 22: 3.75°
#     Embedding 22 → 23: 55.24°
#   Frase 40:
#     Embedding 0 → 1: 75.52°
#     Embedding 1 → 2: 59.95°
#     Embedding 2 → 3: 53.08°
#     Embedding 3 → 4: 57.29°
#     Embedding 4 → 5: 64.21°
#     Embedding 5 → 6: 57.91°
#     Embedding 6 → 7: 65.75°
#     Embedding 7 → 8: 55.61°
#     Embedding 8 → 9: 57.39°
#     Embedding 9 → 10: 52.59°
#     Embedding 10 → 11: 67.48°
#     Embedding 11 → 12: 64.17°
#     Embedding 12 → 13: 63.74°
#     Embedding 13 → 14: 57.63°
#     Embedding 14 → 15: 57.22°
#     Embedding 15 → 16: 62.13°
#     Embedding 16 → 17: 65.66°
#     Embedding 17 → 18: 54.58°
#     Embedding 18 → 19: 43.03°
#     Embedding 19 → 20: 10.14°
#     Embedding 20 → 21: 23.01°
#     Embedding 21 → 22: 9.48°
#     Embedding 22 → 23: 6.88°
#   Frase 41:
#     Embedding 0 → 1: 70.48°
#     Embedding 1 → 2: 69.46°
#     Embedding 2 → 3: 66.56°
#     Embedding 3 → 4: 53.79°
#     Embedding 4 → 5: 63.84°
#     Embedding 5 → 6: 65.45°
#     Embedding 6 → 7: 58.36°
#     Embedding 7 → 8: 58.01°
#     Embedding 8 → 9: 69.30°
#     Embedding 9 → 10: 63.36°
#     Embedding 10 → 11: 64.69°
#     Embedding 11 → 12: 60.86°
#     Embedding 12 → 13: 68.62°
#     Embedding 13 → 14: 57.40°
#     Embedding 14 → 15: 61.75°
#     Embedding 15 → 16: 59.93°
#     Embedding 16 → 17: 23.85°
#     Embedding 17 → 18: 64.28°
#     Embedding 18 → 19: 54.25°
#     Embedding 19 → 20: 28.69°
#     Embedding 20 → 21: 56.37°
#     Embedding 21 → 22: 12.50°
#     Embedding 22 → 23: 53.44°
#   Frase 42:
#     Embedding 0 → 1: 71.74°
#     Embedding 1 → 2: 64.65°
#     Embedding 2 → 3: 58.79°
#     Embedding 3 → 4: 61.38°
#     Embedding 4 → 5: 63.83°
#     Embedding 5 → 6: 69.12°
#     Embedding 6 → 7: 52.11°
#     Embedding 7 → 8: 65.55°
#     Embedding 8 → 9: 67.83°
#     Embedding 9 → 10: 63.01°
#     Embedding 10 → 11: 66.30°
#     Embedding 11 → 12: 67.83°
#     Embedding 12 → 13: 72.75°
#     Embedding 13 → 14: 64.06°
#     Embedding 14 → 15: 56.81°
#     Embedding 15 → 16: 63.72°
#     Embedding 16 → 17: 67.04°
#     Embedding 17 → 18: 36.72°
#     Embedding 18 → 19: 31.00°
#     Embedding 19 → 20: 49.81°
#     Embedding 20 → 21: 49.69°
#     Embedding 21 → 22: 18.22°
#     Embedding 22 → 23: 25.76°
#   Frase 43:
#     Embedding 0 → 1: 76.76°
#     Embedding 1 → 2: 67.79°
#     Embedding 2 → 3: 66.84°
#     Embedding 3 → 4: 72.42°
#     Embedding 4 → 5: 71.32°
#     Embedding 5 → 6: 71.11°
#     Embedding 6 → 7: 52.75°
#     Embedding 7 → 8: 57.53°
#     Embedding 8 → 9: 64.23°
#     Embedding 9 → 10: 70.32°
#     Embedding 10 → 11: 65.90°
#     Embedding 11 → 12: 56.76°
#     Embedding 12 → 13: 55.09°
#     Embedding 13 → 14: 60.91°
#     Embedding 14 → 15: 60.10°
#     Embedding 15 → 16: 60.12°
#     Embedding 16 → 17: 64.85°
#     Embedding 17 → 18: 67.93°
#     Embedding 18 → 19: 69.55°
#     Embedding 19 → 20: 54.54°
#     Embedding 20 → 21: 63.08°
#     Embedding 21 → 22: 54.39°
#     Embedding 22 → 23: 65.53°
#   Frase 44:
#     Embedding 0 → 1: 77.25°
#     Embedding 1 → 2: 68.32°
#     Embedding 2 → 3: 65.33°
#     Embedding 3 → 4: 64.75°
#     Embedding 4 → 5: 66.13°
#     Embedding 5 → 6: 61.16°
#     Embedding 6 → 7: 54.99°
#     Embedding 7 → 8: 64.28°
#     Embedding 8 → 9: 61.50°
#     Embedding 9 → 10: 63.62°
#     Embedding 10 → 11: 58.45°
#     Embedding 11 → 12: 63.42°
#     Embedding 12 → 13: 60.44°
#     Embedding 13 → 14: 52.42°
#     Embedding 14 → 15: 62.01°
#     Embedding 15 → 16: 59.01°
#     Embedding 16 → 17: 49.48°
#     Embedding 17 → 18: 49.73°
#     Embedding 18 → 19: 56.76°
#     Embedding 19 → 20: 50.25°
#     Embedding 20 → 21: 61.03°
#     Embedding 21 → 22: 5.77°
#     Embedding 22 → 23: 10.93°
#   Frase 45:
#     Embedding 0 → 1: 77.35°
#     Embedding 1 → 2: 44.79°
#     Embedding 2 → 3: 58.23°
#     Embedding 3 → 4: 62.42°
#     Embedding 4 → 5: 60.72°
#     Embedding 5 → 6: 59.80°
#     Embedding 6 → 7: 60.17°
#     Embedding 7 → 8: 62.77°
#     Embedding 8 → 9: 54.67°
#     Embedding 9 → 10: 53.94°
#     Embedding 10 → 11: 63.62°
#     Embedding 11 → 12: 60.48°
#     Embedding 12 → 13: 19.18°
#     Embedding 13 → 14: 16.53°
#     Embedding 14 → 15: 27.38°
#     Embedding 15 → 16: 26.57°
#     Embedding 16 → 17: 35.35°
#     Embedding 17 → 18: 22.44°
#     Embedding 18 → 19: 26.98°
#     Embedding 19 → 20: 32.47°
#     Embedding 20 → 21: 44.55°
#     Embedding 21 → 22: 36.26°
#     Embedding 22 → 23: 33.84°
#   Frase 46:
#     Embedding 0 → 1: 72.88°
#     Embedding 1 → 2: 60.67°
#     Embedding 2 → 3: 59.46°
#     Embedding 3 → 4: 66.40°
#     Embedding 4 → 5: 51.25°
#     Embedding 5 → 6: 72.49°
#     Embedding 6 → 7: 56.69°
#     Embedding 7 → 8: 54.94°
#     Embedding 8 → 9: 66.78°
#     Embedding 9 → 10: 62.52°
#     Embedding 10 → 11: 67.30°
#     Embedding 11 → 12: 61.73°
#     Embedding 12 → 13: 56.32°
#     Embedding 13 → 14: 69.75°
#     Embedding 14 → 15: 60.33°
#     Embedding 15 → 16: 63.31°
#     Embedding 16 → 17: 57.91°
#     Embedding 17 → 18: 64.02°
#     Embedding 18 → 19: 67.41°
#     Embedding 19 → 20: 52.80°
#     Embedding 20 → 21: 59.53°
#     Embedding 21 → 22: 35.19°
#     Embedding 22 → 23: 50.83°
#   Frase 47:
#     Embedding 0 → 1: 75.58°
#     Embedding 1 → 2: 70.25°
#     Embedding 2 → 3: 70.29°
#     Embedding 3 → 4: 52.12°
#     Embedding 4 → 5: 41.64°
#     Embedding 5 → 6: 45.57°
#     Embedding 6 → 7: 61.36°
#     Embedding 7 → 8: 52.73°
#     Embedding 8 → 9: 58.96°
#     Embedding 9 → 10: 71.32°
#     Embedding 10 → 11: 58.90°
#     Embedding 11 → 12: 58.01°
#     Embedding 12 → 13: 71.05°
#     Embedding 13 → 14: 62.35°
#     Embedding 14 → 15: 69.34°
#     Embedding 15 → 16: 56.67°
#     Embedding 16 → 17: 67.43°
#     Embedding 17 → 18: 64.50°
#     Embedding 18 → 19: 6.89°
#     Embedding 19 → 20: 18.82°
#     Embedding 20 → 21: 17.90°
#     Embedding 21 → 22: 43.61°
#     Embedding 22 → 23: 19.78°
#   Frase 48:
#     Embedding 0 → 1: 77.07°
#     Embedding 1 → 2: 68.52°
#     Embedding 2 → 3: 70.89°
#     Embedding 3 → 4: 60.83°
#     Embedding 4 → 5: 69.78°
#     Embedding 5 → 6: 60.70°
#     Embedding 6 → 7: 65.52°
#     Embedding 7 → 8: 61.68°
#     Embedding 8 → 9: 56.28°
#     Embedding 9 → 10: 66.15°
#     Embedding 10 → 11: 65.75°
#     Embedding 11 → 12: 23.59°
#     Embedding 12 → 13: 10.63°
#     Embedding 13 → 14: 49.33°
#     Embedding 14 → 15: 54.22°
#     Embedding 15 → 16: 41.49°
#     Embedding 16 → 17: 48.67°
#     Embedding 17 → 18: 27.12°
#     Embedding 18 → 19: 24.59°
#     Embedding 19 → 20: 9.95°
#     Embedding 20 → 21: 23.69°
#     Embedding 21 → 22: 10.26°
#     Embedding 22 → 23: 32.72°
#   Frase 49:
#     Embedding 0 → 1: 70.70°
#     Embedding 1 → 2: 62.37°
#     Embedding 2 → 3: 58.28°
#     Embedding 3 → 4: 47.57°
#     Embedding 4 → 5: 63.58°
#     Embedding 5 → 6: 57.55°
#     Embedding 6 → 7: 64.95°
#     Embedding 7 → 8: 49.41°
#     Embedding 8 → 9: 58.29°
#     Embedding 9 → 10: 66.96°
#     Embedding 10 → 11: 64.97°
#     Embedding 11 → 12: 49.17°
#     Embedding 12 → 13: 54.45°
#     Embedding 13 → 14: 48.33°
#     Embedding 14 → 15: 40.87°
#     Embedding 15 → 16: 65.65°
#     Embedding 16 → 17: 64.85°
#     Embedding 17 → 18: 11.99°
#     Embedding 18 → 19: 35.30°
#     Embedding 19 → 20: 15.04°
#     Embedding 20 → 21: 44.55°
#     Embedding 21 → 22: 45.55°
#     Embedding 22 → 23: 16.81°
#   Frase 50:
#     Embedding 0 → 1: 67.91°
#     Embedding 1 → 2: 63.57°
#     Embedding 2 → 3: 59.79°
#     Embedding 3 → 4: 65.13°
#     Embedding 4 → 5: 57.14°
#     Embedding 5 → 6: 52.32°
#     Embedding 6 → 7: 67.78°
#     Embedding 7 → 8: 68.24°
#     Embedding 8 → 9: 64.31°
#     Embedding 9 → 10: 60.25°
#     Embedding 10 → 11: 54.23°
#     Embedding 11 → 12: 55.11°
#     Embedding 12 → 13: 54.53°
#     Embedding 13 → 14: 44.38°
#     Embedding 14 → 15: 64.91°
#     Embedding 15 → 16: 61.19°
#     Embedding 16 → 17: 46.22°
#     Embedding 17 → 18: 19.69°
#     Embedding 18 → 19: 8.29°
#     Embedding 19 → 20: 30.23°
#     Embedding 20 → 21: 29.60°
#     Embedding 21 → 22: 2.11°
#     Embedding 22 → 23: 58.87°
#   Frase 51:
#     Embedding 0 → 1: 71.74°
#     Embedding 1 → 2: 64.65°
#     Embedding 2 → 3: 58.79°
#     Embedding 3 → 4: 61.38°
#     Embedding 4 → 5: 63.83°
#     Embedding 5 → 6: 69.12°
#     Embedding 6 → 7: 52.11°
#     Embedding 7 → 8: 65.55°
#     Embedding 8 → 9: 67.83°
#     Embedding 9 → 10: 63.01°
#     Embedding 10 → 11: 66.30°
#     Embedding 11 → 12: 67.83°
#     Embedding 12 → 13: 72.75°
#     Embedding 13 → 14: 64.06°
#     Embedding 14 → 15: 56.81°
#     Embedding 15 → 16: 63.72°
#     Embedding 16 → 17: 67.04°
#     Embedding 17 → 18: 36.72°
#     Embedding 18 → 19: 31.00°
#     Embedding 19 → 20: 49.81°
#     Embedding 20 → 21: 49.69°
#     Embedding 21 → 22: 18.22°
#     Embedding 22 → 23: 25.76°
#   Frase 52:
#     Embedding 0 → 1: 79.22°
#     Embedding 1 → 2: 49.33°
#     Embedding 2 → 3: 40.51°
#     Embedding 3 → 4: 46.85°
#     Embedding 4 → 5: 49.43°
#     Embedding 5 → 6: 60.34°
#     Embedding 6 → 7: 69.20°
#     Embedding 7 → 8: 63.00°
#     Embedding 8 → 9: 65.20°
#     Embedding 9 → 10: 52.70°
#     Embedding 10 → 11: 47.80°
#     Embedding 11 → 12: 55.71°
#     Embedding 12 → 13: 68.84°
#     Embedding 13 → 14: 55.45°
#     Embedding 14 → 15: 54.87°
#     Embedding 15 → 16: 55.60°
#     Embedding 16 → 17: 49.49°
#     Embedding 17 → 18: 62.11°
#     Embedding 18 → 19: 68.77°
#     Embedding 19 → 20: 46.63°
#     Embedding 20 → 21: 35.57°
#     Embedding 21 → 22: 16.62°
#     Embedding 22 → 23: 37.19°
#   Frase 53:
#     Embedding 0 → 1: 70.34°
#     Embedding 1 → 2: 69.56°
#     Embedding 2 → 3: 60.51°
#     Embedding 3 → 4: 60.05°
#     Embedding 4 → 5: 49.63°
#     Embedding 5 → 6: 61.15°
#     Embedding 6 → 7: 75.81°
#     Embedding 7 → 8: 64.77°
#     Embedding 8 → 9: 73.44°
#     Embedding 9 → 10: 56.50°
#     Embedding 10 → 11: 61.07°
#     Embedding 11 → 12: 59.01°
#     Embedding 12 → 13: 55.15°
#     Embedding 13 → 14: 61.81°
#     Embedding 14 → 15: 62.61°
#     Embedding 15 → 16: 13.08°
#     Embedding 16 → 17: 35.77°
#     Embedding 17 → 18: 40.16°
#     Embedding 18 → 19: 51.79°
#     Embedding 19 → 20: 51.62°
#     Embedding 20 → 21: 53.56°
#     Embedding 21 → 22: 20.51°
#     Embedding 22 → 23: 33.25°
#   Frase 54:
#     Embedding 0 → 1: 77.35°
#     Embedding 1 → 2: 44.79°
#     Embedding 2 → 3: 58.23°
#     Embedding 3 → 4: 62.42°
#     Embedding 4 → 5: 60.72°
#     Embedding 5 → 6: 59.80°
#     Embedding 6 → 7: 60.17°
#     Embedding 7 → 8: 62.77°
#     Embedding 8 → 9: 54.67°
#     Embedding 9 → 10: 53.94°
#     Embedding 10 → 11: 63.62°
#     Embedding 11 → 12: 60.48°
#     Embedding 12 → 13: 19.18°
#     Embedding 13 → 14: 16.53°
#     Embedding 14 → 15: 27.38°
#     Embedding 15 → 16: 26.57°
#     Embedding 16 → 17: 35.35°
#     Embedding 17 → 18: 22.44°
#     Embedding 18 → 19: 26.98°
#     Embedding 19 → 20: 32.47°
#     Embedding 20 → 21: 44.55°
#     Embedding 21 → 22: 36.26°
#     Embedding 22 → 23: 33.84°
#   Frase 55:
#     Embedding 0 → 1: 69.31°
#     Embedding 1 → 2: 66.56°
#     Embedding 2 → 3: 71.16°
#     Embedding 3 → 4: 53.22°
#     Embedding 4 → 5: 60.64°
#     Embedding 5 → 6: 67.05°
#     Embedding 6 → 7: 59.08°
#     Embedding 7 → 8: 61.66°
#     Embedding 8 → 9: 56.74°
#     Embedding 9 → 10: 43.70°
#     Embedding 10 → 11: 44.93°
#     Embedding 11 → 12: 52.01°
#     Embedding 12 → 13: 63.35°
#     Embedding 13 → 14: 64.16°
#     Embedding 14 → 15: 51.78°
#     Embedding 15 → 16: 45.05°
#     Embedding 16 → 17: 52.90°
#     Embedding 17 → 18: 57.02°
#     Embedding 18 → 19: 55.78°
#     Embedding 19 → 20: 55.00°
#     Embedding 20 → 21: 9.98°
#     Embedding 21 → 22: 31.68°
#     Embedding 22 → 23: 47.77°
#   Frase 56:
#     Embedding 0 → 1: 70.70°
#     Embedding 1 → 2: 62.37°
#     Embedding 2 → 3: 58.28°
#     Embedding 3 → 4: 47.57°
#     Embedding 4 → 5: 63.58°
#     Embedding 5 → 6: 57.55°
#     Embedding 6 → 7: 64.95°
#     Embedding 7 → 8: 49.41°
#     Embedding 8 → 9: 58.29°
#     Embedding 9 → 10: 66.96°
#     Embedding 10 → 11: 64.97°
#     Embedding 11 → 12: 49.17°
#     Embedding 12 → 13: 54.45°
#     Embedding 13 → 14: 48.33°
#     Embedding 14 → 15: 40.87°
#     Embedding 15 → 16: 65.65°
#     Embedding 16 → 17: 64.85°
#     Embedding 17 → 18: 11.99°
#     Embedding 18 → 19: 35.30°
#     Embedding 19 → 20: 15.04°
#     Embedding 20 → 21: 44.55°
#     Embedding 21 → 22: 45.55°
#     Embedding 22 → 23: 16.81°
